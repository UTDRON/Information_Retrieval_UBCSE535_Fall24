# %%
import pandas as pd
import re
from datasets import Dataset
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_dataset.csv')  # Replace with your dataset path

# Preprocessing function
def preprocess_text(text):
    """
    Clean and preprocess the text data.
    - Lowercases the text
    - Removes URLs, special characters, and extra whitespace
    - Removes stopwords
    """
    text = text.lower()  # Lowercase
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra whitespace
    words = text.split()
    text = " ".join(word for word in words if word not in stop_words)  # Remove stopwords
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Apply preprocessing
data['text'] = data['text'].astype(str).apply(preprocess_text)

# Drop duplicates and handle missing values
data.drop_duplicates(subset='text', inplace=True)
data.dropna(subset=['text', 'label'], inplace=True)

# Map labels to integers
label_map = {'chit-chat': 0, 'topic-specific': 1}
data['label'] = data['label'].map(label_map)

# Limit "chit-chat" data to 70,000 samples
chitchat_data = data[data['label'] == label_map['chit-chat']].sample(n=70000, random_state=42)
topic_data = data[data['label'] == label_map['topic-specific']]

# Combine the datasets and shuffle
limited_data = pd.concat([chitchat_data, topic_data]).sample(frac=1, random_state=42).reset_index(drop=True)

# Split into train and validation datasets
from sklearn.model_selection import train_test_split

train_texts, val_texts, train_labels, val_labels = train_test_split(
    limited_data['text'], limited_data['label'], test_size=0.2, stratify=limited_data['label'], random_state=42
)

# Convert to HuggingFace Dataset
train_dataset = Dataset.from_dict({'text': train_texts.tolist(), 'label': train_labels.tolist()})
val_dataset = Dataset.from_dict({'text': val_texts.tolist(), 'label': val_labels.tolist()})

# Save the datasets for reuse
train_dataset.save_to_disk("/content/drive/MyDrive/Colab Notebooks/train_dataset")
val_dataset.save_to_disk("/content/drive/MyDrive/Colab Notebooks/val_dataset")

print("Train and validation datasets created with limited 'chit-chat' data, preprocessing, and stopword removal.")

# %%
import pandas as pd
import re
from datasets import Dataset
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments, EarlyStoppingCallback
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch


# Load the tokenizer
model_name = "albert-base-v2"  # Use ALBERT model
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Tokenize datasets
def preprocess_function(examples):
    return tokenizer(examples['text'], truncation=True, padding=True, max_length=128)

train_dataset = train_dataset.map(preprocess_function, batched=True)
val_dataset = val_dataset.map(preprocess_function, batched=True)

# Load the model
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Metrics calculation
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = torch.argmax(torch.tensor(logits), dim=-1).numpy()
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average='binary')
    acc = accuracy_score(labels, predictions)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# Training arguments with regularization and early stopping
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,  # Regularization term
    logging_dir="./logs",
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    save_total_limit=2,
    seed=42,
    fp16=True,  # Enable mixed-precision training
)

# Initialize Trainer with EarlyStoppingCallback
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=1)],  # Stop after 3 epochs with no improvement
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()
print("Evaluation Results:", results)

# Save the model
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/albert_text_classifier")
tokenizer.save_pretrained("/content/drive/MyDrive/Colab Notebooks/albert_text_classifier")
# Out:
# Map:   0%|          | 0/113600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/28401 [00:00<?, ? examples/s]
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-4-ce10b251d794>:52: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='21300' max='21300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21300/21300 54:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000200</td>
#       <td>0.010371</td>
#       <td>0.998134</td>
#       <td>0.998160</td>
#       <td>0.998333</td>
#       <td>0.997986</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.006189</td>
#       <td>0.998768</td>
#       <td>0.998785</td>
#       <td>0.998612</td>
#       <td>0.998958</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.006659</td>
#       <td>0.998803</td>
#       <td>0.998819</td>
#       <td>0.999166</td>
#       <td>0.998472</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1776' max='1776' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1776/1776 01:32]
#     </div>
# Evaluation Results: {'eval_loss': 0.006188678089529276, 'eval_accuracy': 0.9987676490264428, 'eval_f1': 0.9987850175304613, 'eval_precision': 0.9986116895737887, 'eval_recall': 0.9989584056662731, 'eval_runtime': 92.8062, 'eval_samples_per_second': 306.025, 'eval_steps_per_second': 19.137, 'epoch': 3.0}
# ('/content/drive/MyDrive/Colab Notebooks/albert_text_classifier/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/albert_text_classifier/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/albert_text_classifier/spiece.model',
#  '/content/drive/MyDrive/Colab Notebooks/albert_text_classifier/added_tokens.json',
#  '/content/drive/MyDrive/Colab Notebooks/albert_text_classifier/tokenizer.json')

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

# Load the saved model and tokenizer
model_path = "/content/drive/MyDrive/Colab Notebooks/albert_text_classifier"
model = AutoModelForSequenceClassification.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Move model to device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def classify_text(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512).to(device)

    # Get predictions
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Convert logits to probabilities
    probabilities = torch.nn.functional.softmax(logits, dim=-1)

    # Get predicted label based on adjusted threshold (for example, 0.55)
    predicted_label = torch.argmax(probabilities, dim=-1).item()

    # Get the probability of the predicted label
    predicted_probability = probabilities[0][predicted_label].item()

    # Optionally check if the confidence is low and make adjustments
    if predicted_probability < 0.55:  # Change 0.55 to a higher value if needed
        predicted_label = 1  # For example, force "topic-specific" if low confidence

    # Map label to corresponding text
    label_map = {0: 'Chitchat', 1: 'Topic-specific'}
    return label_map[predicted_label]



# Chat terminal loop
print("Chat terminal is running. Type 'exit' to stop.")
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() == 'exit':
        print("Exiting chat terminal...")
        break

    # Classify the input text
    prediction = classify_text(user_input)

    # Print the result
    print(f"Bot: {prediction}")
# Out:
# Chat terminal is running. Type 'exit' to stop.
# You: what is GHI and how it  attempts to measure and track hunger globally
# Bot: Chitchat
# You: Global Hunger Index GHI is a tool that attempts to measure and track hunger globally
# Bot: Topic-specific
# You: GlobalGHI is a tool that attempts to measure and track hunger globally
# Bot: Chitchat
# You: GHI is a tool that attempts to measure and track hunger globally
# Bot: Chitchat
# You: Bechuanaland National Airways was the national airline of the Bechuanaland Protectorate and was based in Francistown
# Bot: Topic-specific
# You: After independence Jawaharlal Nehru the first prime minister of India initiated reforms to promote higher education and science and technology in India The Indian Institute of Technology IIT conceived by a 22 member committee of scholars and entrepreneurs in order to promote technical education was inaugurated on 18 August 1951 at Kharagpur in West Bengal by the minister of education Maulana Abul Kalam Azad More IITs were soon opened in Bombay Madras Kanpur and Delhi as well in the late 1950s and early 1960s along with the regional RECs now National Institutes of Technology NIT Beginning in the 1960s close ties with the Soviet Union enabled the Indian Space Research Organisation to rapidly develop the Indian space program and advance nuclear power in India even after the first nuclear test explosion by India on 18 May 1974 at Pokhran India accounts for about 10 of all expenditure on research and development in Asia and the number of scientific publications grew by 45 over the five years to 2007 However according to former Indian science and technology minister Kapil Sibal India is lagging in science and technology compared to developed countries India has only 140 researchers per 1 000 000 population compared to 4 651 in the United States India invested US 3 7 billion in science and technology in 2002 2003 For comparison China invested about four times more than India while the United States invested approximately 75 times more than India on science and technology Research and development spending grew to US 17 2 in 2020 2021 While India has increased its output of scientific papers fourfold between 2000 and 2015 overtaking Russia and France in absolute number of papers per year that rate has been exceeded by China and Brazil Indian papers generate fewer cites than average and relative to its population it has few scientists In the quality adjusted Nature Index India was ranked ninth worldwide in 2023 and recorded faster growth than China in this year albeit from a lower base India is ranked 39th in the Global Innovation Index in 2024
# Bot: Topic-specific
# You: who is the first prime minister of India that created Indian Institute of Technology
# Bot: Topic-specific
# You: which prime minister of India that created Indian Institute of Technology
# Bot: Topic-specific
# You: who was known for his contributions to structuralist macroeconomics?
# Bot: Chitchat
# You: who was known for his contributions to structuralist macroeconomics
# Bot: Chitchat
# You: American economist who was known for his contributions to structuralist macroeconomics?
# Bot: Chitchat
# You: You: American economist who was known for his contributions to structuralist macroeconomics
# Bot: Chitchat
# You: who was the Arnhold Professor of International Cooperation
# Bot: Chitchat
# You: Lance Jerome Taylor May 25 1940 to August 15 2022 was an American economist who was known for his contributions to structuralist macroeconomics He was the Arnhold Professor of International Cooperation and Development and director of the Center for Economic Policy Analysis at the New School for Social Research As a professor he taught students who come in with a critical attitude about economics aiming to encourage that progressive perspective while providing them the standard technical tools of economics According to Taylor structuralist economics sought to understand the macroeconomy through its major institutions and distributive relationships across productive sectors and social groups He was a visiting scholar or policy advisor in over 25 countries including Chile Brazil Mexico Nicaragua Cuba Russia Egypt Tanzania Zimbabwe South Africa Pakistan India and Thailand He taught and worked at the New School for Social Research since 1993 Taylor was previously associate professor of economics at Harvard and Professor of Economics at MIT year long visiting professorships at U Minnesota Univesidade de Brasilia Delhi School of Economics and Stockholm School of Economics He received a B S degree with honors in mathematics from the California Institute of Technology in 1962 and after study at Lund University Sweden and a Fulbright Fellowship in mathematics and economics he received a Ph D in economics from Harvard University in 1968
# Bot: Topic-specific
# You: exit
# Exiting chat terminal...

# %%
from datasets import load_from_disk

# Step 1: Load the datasets
train_dataset = load_from_disk("/content/drive/MyDrive/Colab Notebooks/train_dataset")
val_dataset = load_from_disk("/content/drive/MyDrive/Colab Notebooks/val_dataset")

from collections import Counter
import re

def extract_common_phrases(dataset, label=1, n_phrases=10):
    """
    Extract common phrases from the dataset.
    :param dataset: The dataset containing 'text' and 'label'.
    :param label: The label corresponding to topic-specific texts.
    :param n_phrases: Number of common phrases to extract.
    :return: List of common phrases.
    """
    # Filter dataset for topic-specific texts
    topic_texts = [item['text'] for item in dataset if item['label'] == label]

    # Tokenize and clean text
    phrases = []
    for text in topic_texts:
        # Remove non-alphanumeric characters and tokenize
        tokens = re.findall(r'\b\w+\b', text.lower())
        phrases.extend([' '.join(tokens[i:i+3]) for i in range(len(tokens)-2)])  # Extract 3-grams

    # Count most common phrases
    common_phrases = Counter(phrases).most_common(n_phrases)
    return [phrase[0] for phrase in common_phrases]

# Extract common phrases
common_phrases = extract_common_phrases(train_dataset, label=1, n_phrases=20)
print("Common Phrases:", common_phrases)

from sklearn.feature_extraction.text import TfidfVectorizer

def generate_templates_tfidf(dataset, label=1, n_templates=10):
    """
    Generate topic-specific templates using TF-IDF.
    :param dataset: The dataset containing 'text' and 'label'.
    :param label: The label corresponding to topic-specific texts.
    :param n_templates: Number of templates to generate.
    :return: List of generated templates.
    """
    # Filter dataset for topic-specific texts
    topic_texts = [item['text'] for item in dataset if item['label'] == label]

    # Create a TF-IDF vectorizer
    vectorizer = TfidfVectorizer(ngram_range=(2, 3), stop_words='english')  # Use bigrams and trigrams
    tfidf_matrix = vectorizer.fit_transform(topic_texts)

    # Extract top phrases
    scores = zip(vectorizer.get_feature_names_out(), tfidf_matrix.sum(axis=0).tolist()[0])
    sorted_phrases = sorted(scores, key=lambda x: x[1], reverse=True)
    return [phrase for phrase, score in sorted_phrases[:n_templates]]

# Extract TF-IDF phrases
tfidf_phrases = generate_templates_tfidf(train_dataset, label=1, n_templates=20)
print("TF-IDF Phrases:", tfidf_phrases)

topic_templates = list(set(common_phrases + tfidf_phrases))
print("Combined Topic Templates:", topic_templates)
# Out:
# Common Phrases: ['national wildlife refuge', 'men basketball tournament', 'automatic bid ncaa', 'register historic places', 'national register historic', 'new york city', 'united states house', 'states house representatives', 'listed national register', 'new south wales', 'conference automatic bid', 'bid ncaa division', 'park national park', 'km sq mi', 'ice hockey tournament', 'world war ii', 'house representatives elections', 'men ice hockey', 'national park national', 'bid ncaa tournament']
# TF-IDF Phrases: ['united states', 'national park', 'new york', 'basketball tournament', 'elections held', 'high school', 'tournament held', 'house representatives', 'nature reserve', 'ncaa division', 'men basketball', 'science fiction', 'science technology', 'took place', 'higher education', 'men basketball tournament', 'automatic bid', 'bid ncaa', 'united kingdom', 'automatic bid ncaa']
# Combined Topic Templates: ['united states house', 'higher education', 'listed national register', 'national register historic', 'new york city', 'high school', 'park national park', 'tournament held', 'men basketball tournament', 'united states', 'national wildlife refuge', 'km sq mi', 'new south wales', 'national park', 'automatic bid', 'united kingdom', 'conference automatic bid', 'ice hockey tournament', 'elections held', 'new york', 'world war ii', 'house representatives', 'house representatives elections', 'science technology', 'national park national', 'men ice hockey', 'science fiction', 'automatic bid ncaa', 'men basketball', 'register historic places', 'bid ncaa tournament', 'nature reserve', 'took place', 'bid ncaa division', 'ncaa division', 'states house representatives', 'bid ncaa', 'basketball tournament']

# %%
import pickle

with open("/content/drive/MyDrive/Colab Notebooks/template_embeddings.pkl", "wb") as f:
    pickle.dump(template_embeddings, f)

sentence_model.save("/content/drive/MyDrive/Colab Notebooks/sentence_transformer_model")

# %%
import pickle
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Paths
save_dir = "/content/drive/MyDrive/Colab Notebooks/albert_text_classifier"
embeddings_path = "/content/drive/MyDrive/Colab Notebooks/template_embeddings.pkl"
sentence_transformer_path = "/content/drive/MyDrive/Colab Notebooks/sentence_transformer_model"

# Step 1: Load ALBERT model and tokenizer
albert_model = AutoModelForSequenceClassification.from_pretrained(save_dir)
tokenizer = AutoTokenizer.from_pretrained(save_dir)

# Step 2: Load SentenceTransformer model
sentence_model = SentenceTransformer(sentence_transformer_path)

# Step 3: Load template embeddings
with open(embeddings_path, "rb") as f:
    template_embeddings = pickle.load(f)

# Ensemble classification function
def ensemble_classifys(text, albert_model, tokenizer, sentence_model, template_embeddings, threshold=0.7):
    """
    Ensemble model combining cosine similarity and ALBERT classification.
    :param text: Input text for classification.
    :param albert_model: Trained ALBERT model.
    :param tokenizer: Tokenizer for the ALBERT model.
    :param sentence_model: Pre-trained SentenceTransformer model.
    :param template_embeddings: Precomputed template embeddings.
    :param threshold: Cosine similarity threshold for topic-specific classification.
    :return: Predicted label ('Chitchat' or 'Topic-specific').
    """
    # Cosine similarity-based classification
    text_embedding = sentence_model.encode([text])[0]
    similarities = cosine_similarity([text_embedding], template_embeddings).flatten()
    max_similarity = max(similarities)

    if max_similarity > threshold:
        return "Topic-specific"

    # ALBERT classification
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    outputs = albert_model(**inputs)
    probs = torch.softmax(outputs.logits, dim=-1).detach().cpu().numpy()[0]
    predicted_label = "Topic-specific" if probs[1] > probs[0] else "Chitchat"

    return predicted_label

# Example Usage
input_text = "Explain the greenhouse effect."
result = ensemble_classifys(input_text, albert_model, tokenizer, sentence_model, template_embeddings)
print(f"Classification Result: {result}")
# Out:
# Classification Result: Chitchat

# %%
while True:
  # Example usage
  user_input = input("User: ")
  if user_input.lower() == 'exit':
    print("GoodBye!")
    break
  user_input = preprocess_text(user_input)
  prediction = ensemble_classifys(input_text, albert_model, tokenizer, sentence_model, template_embeddings)
  # prediction = ensemble_classifying(user_input)
  print(f"Label: {prediction}")
# Out:
# User: when was world war ii officially started?
# Label: Chitchat
# User: exit
# GoodBye!

# %%
while True:
  # Example usage
  user_input = input("User: ")
  if user_input.lower() == 'exit':
    print("GoodBye!")
    break
  user_input = preprocess_text(user_input)
  prediction = ensemble_classify(user_input, model, tokenizer)
  print(f"Label: {prediction}")
# Out:
# User: when was world war ii officially started?
# Label: Topic-specific
# User: when is the election for united states house of reps held?
# Label: Topic-specific
# User: hi how are you?
# Label: Chitchat
# User: oh
# Label: Chitchat
# User: how was your day? mine was very great and really good weather too!
# Label: Chitchat
# User: exit
# GoodBye!

# %%
val_phrases_flat
# Out:
# ['professional wrestling promotion based halifax nova scotia',
#  'professional wrestlers managers',
#  'play color commentators',
#  'interviewers referees',
#  'quivira national wildlife refuge south central kansas united states',
#  'rare inland marshes',
#  'town stafford',
#  'mostly northeastern stafford county small parts',
#  'southwestern rice northwestern reno counties',
#  'central flyway migration route salt',
#  'refuge',
#  'combine endow refuge',
#  'large variety birds',
#  'many birds uncommon parts',
#  'even central part continent january quivira nwr cheyenne bottoms wildlife area',
#  'one wonders',
#  'kansas quivira',
#  'nwr one places united states ramsar list',
#  'wetland international importance',
#  'fortune small business fsb american magazine',
#  'times',
#  'year',
#  'inc american',
#  'small business services',
#  'million small business owners',
#  'united states',
#  'cea list laboratory integration systems technology french laboratoire int gration de syst mes et des technologies',
#  'one three institutes french cea technological research division cea tech institute',
#  'digital systems',
#  'international association accounting education research',
#  'non profit organization',
#  'excellence accounting education research organization',
#  'accounting academics',
#  'maximum contribution development excellent accounting standards',
#  'fitness culture',
#  'sociocultural phenomenon',
#  'exercise physical fitness',
#  'gym culture physical exercises locations',
#  'gyms wellness',
#  'health clubs popular activity international survey',
#  'world total adult population',
#  'fitness centres',
#  'regular exercisers',
#  'currently gym type activities',
#  'physical fitness shown benefit individuals',
#  'inner outer health fitness culture',
#  'modern technology social media platforms',
#  'tianwen chinese',
#  'tw',
#  'chinese traditional chinese',
#  'interplanetary mission',
#  'robotic spacecraft mars',
#  'consisting spacecraft orbiter',
#  'two deployable cameras lander remote camera zhurong rover spacecraft',
#  'total mass',
#  'nearly five tons',
#  'one heaviest probes',
#  'mars',
#  'scientific instruments first series planned missions',
#  'exploration china program mission scientific objectives',
#  'investigation martian surface geology internal structure search indications',
#  'current past presence water characterization space environment atmosphere mars mission',
#  'wenchang spacecraft launch site july long march heavy lift launch vehicle',
#  'seven months transit inner solar system spacecraft',
#  'martian orbit february',
#  'next three months probe studied target landing sites reconnaissance orbit',
#  'rover portion mission',
#  'mars',
#  'china third nation',
#  'soft landing',
#  'communication martian surface soviet union united states',
#  'zhurong rover',
#  'martian surface',
#  'descent ramps',
#  'platform successful deployment rover china',
#  'second nation accomplish feat united states addition',
#  'china second nation orbit',
#  'landing rovering mission mars',
#  'attempt tianwen',
#  'also second mission capture audio recordings martian surface united states perseverance rover smallsat',
#  'zhurong rover martian surface',
#  'drop camera',
#  'well tianwen lander mass less kg tianwen remote camera lightest artificial object mars',
#  'second deployable camera tdc mars orbit',
#  'working position orbiter',
#  'images',
#  'orbiter components',
#  'chinese flag january',
#  'chinese new year september mission',
#  'world space award international astronautical federation tianwen mission second three martian exploration missions',
#  'july window united arab emirates space agency hope orbiter nasa mars mission',
#  'landed perseverance rover',
#  'ingenuity helicopter drone',
#  'danger disease',
#  'zoth ommog europe lp cd formats',
#  'black market music third studio album british alternative rock band placebo album',
#  'nine months record',
#  'late mid longest band',
#  'october record label hut four singles',
#  'album taste men slave wage special k black eyed album',
#  'number uk albums chart',
#  'generally favourable reaction music critics',
#  'indian economic service',
#  'e',
#  'inter ministerial inter departmental central civil service group executive branch government',
#  'india unique aspect service cadre posts',
#  'various departments ministries central government',
#  'highly specialised professional service',
#  'government india',
#  'economic analysis policy advice',
#  'raven',
#  'aboriginal values',
#  'charitable organization',
#  'financial resources',
#  'aboriginal nations',
#  'canada',
#  'industrial development',
#  'traditional ways',
#  'life manner addresses climate',
#  'ecological sustainability challenges',
#  'albrighton v rpa hospital australian tort law case',
#  'application bolam',
#  'professional negligence',
#  'national park',
#  'also french parc marin des mangroves muanda marine reserve protected area ramsar wetland democratic republic congo country marine park notable mangrove forests',
#  'protection endangered manatee population',
#  'situated mouth congo river',
#  'distinct ones',
#  'south asia',
#  'separate type mangrove forests',
#  'typical democratic republic congo park',
#  'taiwan blackfoot disease socio medical service memorial house traditional chinese',
#  'chinese pinyin',
#  'w ji',
#  'ng li j ni ngu',
#  'former clinic',
#  'yonglong village beimen district tainan',
#  'taiwan',
#  'hotel historic tavern hotel located battenville washington county new york',
#  'timber frame',
#  'vernacular design federal greek revival details',
#  'stoops brinkman house',
#  'national register historic places',
#  'missouri valley conference baseball tournament',
#  'eight teams',
#  'double elimination tournament',
#  'illinois state duffy bass field normal illinois winner tournament earn conference',
#  'news world snooker tournament professional snooker tournament sponsored news world tournament joe davis matches',
#  'fred davis',
#  'joe frames',
#  'overall news world snooker tournament',
#  'biju patnaik university technology',
#  'bput',
#  'rourkela state odisha india colleges',
#  'university college',
#  'constituent affiliated type colleges',
#  'private unaided public private partnership ppp private aided government',
#  'college',
#  'government odisha private unaided college funded private organisation private public partnership ppp college',
#  'thus partially funded government',
#  'cuisine de madame',
#  'marie brard name e saint ange',
#  'cuisine bourgeoise',
#  'technical descriptions kitchen equipment day',
#  'bonne cuisine author',
#  'cooking column husband magazine le pot',
#  'twenty years much content',
#  'magazine book',
#  'de la bonne cuisine fran aise current title',
#  'modest updating original work publisher editions',
#  'title',
#  'la cuisine de madame saint ange',
#  'many american chefs',
#  'cooking teachers',
#  'french cuisine',
#  'significant influence',
#  'madeleine kamman julia child paul aratow co founder chez panisse aratow translated english',
#  'book',
#  'equipment tastes reviewers',
#  'useful cooking',
#  'work dishes',
#  'delicious extensive advice',
#  'book cries',
#  'indian hospitals',
#  'hospitals',
#  'tuberculosis sanatoria',
#  'general hospitals',
#  'indigenous peoples',
#  'canada',
#  'th century hospitals',
#  'indigenous tuberculosis patients general population fear',
#  'health officials',
#  'indian',
#  'many hospitals',
#  'indian reserves',
#  'reserve hospitals others',
#  'nearby towns',
#  'nancy lake state recreation area',
#  'park',
#  'willow matanuska susitna borough alaska',
#  'specifically recreational use park home hundred lakes',
#  'well extensive wetlands landscape park',
#  'glacial retreats',
#  'time',
#  'first inhabitants',
#  'russian exploration',
#  'white settlement due commerce presence gold nancy lake state recreation site',
#  'smaller acres',
#  'site',
#  'water related activities',
#  'popular draw visitors',
#  'smaller parks',
#  'many guests',
#  'fauna area',
#  'large mammals',
#  'moose',
#  'waterways',
#  'alaska department fish game',
#  'return marketing investment romi contribution profit attributable marketing net marketing spending divided marketing',
#  'romi',
#  'return investment roi metrics marketing kind investment',
#  'instead money',
#  'plants inventories',
#  'capital expenditure capex marketing funds',
#  'marketing spending',
#  'current period operational expenditure opex idea',
#  'market response',
#  'new terms',
#  'roi romi',
#  'periods',
#  'spending',
#  'justified romi positive survey',
#  'nearly senior marketing managers',
#  'romi metric useful purpose romi measure degree spending marketing',
#  'profits',
#  'pressure show return activities',
#  'rabindranath tagore international institute cardiac sciences rtiics',
#  'rabindranath tagore hospital mukundapur kolkata west bengal india multispeciality tertiary care unit narayana health group',
#  'nabh',
#  'multi super speciality quaternary care hospital established year rtiics',
#  'operation',
#  'th generation da vinci robot four state art catheterisation laboratories hour emergency facilities rtiics',
#  'services people',
#  'west bengal neighbouring states',
#  'bangladesh bhutan myanmar',
#  'clinical technical expertise',
#  'proven time institute',
#  'quaternary care services cardiac surgery heart transplants',
#  'interventional cardiology pacemaker device therapy electro physiology preventive cardiology',
#  'c market serbian supermarket chain',
#  'c market biggest retail chain serbia',
#  'today part',
#  'maxi c market stores',
#  'maxi mini maxi chain',
#  'delta',
#  'c market first company',
#  'supermarket chain serbia',
#  'yugoslavia first supermarket',
#  'belgrade capital serbia',
#  'nicolau island opening tournament portuguese torneio de abertura de nicolau capeverdean crioulo alupec alupek',
#  'u',
#  'di san nikolau opening tournament competition equivalent league cup',
#  'season island nicolau cape verde competition',
#  'nicolau regional football association associa regional de futebol de nicolau arfsn seasons',
#  'one portion seasons',
#  'two groups top club group final match',
#  'seven rounds',
#  'another club winner points',
#  'sc atl tico',
#  'probably fourth win title',
#  'atl tico',
#  'recent club',
#  'belo horizonte three clubs',
#  'tico belo horizonte leader',
#  'three clubs',
#  'three titles',
#  'three clubs',
#  'nearly title total season cancelled due financial concerns',
#  'martinique new york broadway curio collection hilton room hotel west nd street',
#  'broadway manhattan new york city',
#  'henry janeway hardenbergh',
#  'william r h martin headed rogers peet business french renaissance style martinique',
#  'three sections',
#  'hotel new york city',
#  'landmark part historic hotels america',
#  'hotel rooms hotel',
#  'irregular site facades',
#  'broadway west rd street north nd street south three sides facade',
#  'glazed brick terracotta limestone balconies',
#  'large green mansard roof',
#  'dormer windows',
#  'hotel various ornately decorated public rooms',
#  'lobby cafe dining rooms ground level grill room basement ballrooms',
#  'second floor modern day hotel',
#  'two restaurants exhibition space martin',
#  'land hotel first section hotel rd street',
#  'originally operated apartment hotel martinique',
#  'hotel coleman',
#  'hotel',
#  'foreclosure',
#  'frank w kridel',
#  'hotel',
#  'building robert selby eugene moses',
#  'martinique welfare hotel housing hundreds families welfare hotel',
#  'negative reputation',
#  'u',
#  'jonathan kozol study rachel children',
#  'homeless families america developer harold thurman',
#  'building owners',
#  'holiday inn franchise october hotel',
#  'radisson chain',
#  'hilton curio collection division martinique',
#  'foreclosure burnett equities',
#  'hotel',
#  'economy',
#  'heavily integrated economy russia',
#  'russian ruble currency abkhazia',
#  'modest economic upswing',
#  'south ossetia war russia',
#  'subsequent recognition abkhazia independence half abkhazia state budget financed aid money russia abkhazia state budget financed aid money russia budget',
#  'local income',
#  'metropolitan hospital center mhc',
#  'metropolitan hospital hospital east harlem new york city',
#  'new york medical college',
#  'oldest partnership hospital private medical school united states',
#  'hhc largest municipal hospital healthcare system country',
#  'good fellows',
#  'john oldham',
#  'standard tune',
#  'caesar',
#  'long original copy ballad located national library scotland',
#  'available public consumption',
#  'massachusetts educational theater guild',
#  'metg',
#  'previously known massachusetts high school drama guild theater arts',
#  'massachusetts',
#  'middle secondary school students teachers metg',
#  'statewide high school theatre festival',
#  'pennsylvania institute technology p pentech private junior college technical school upper providence township delaware county pennsylvania',
#  'media college',
#  'students',
#  'middle states commission higher education',
#  'mad capsule markets',
#  'mad capsule market',
#  'japanese band',
#  'active band',
#  'known experimental style',
#  'various kinds electronic music punk rock',
#  'scientology movie british documentary film scientology',
#  'john dower',
#  'louis theroux film',
#  'unconventional approach subject matter',
#  'young actors',
#  'parts',
#  'high profile scientologists',
#  'scenes',
#  'ex members incidents',
#  'senior church management church scientology',
#  'filmmakers',
#  'surveillance',
#  'film scientology movie',
#  'london film festival october',
#  'limited theatrical release united kingdom october bbc films north american release march magnolia pictures film',
#  'positive reviews critics',
#  'jehangir hospital bed hospital pune',
#  'maharashtra india sir cowasji jehangir lady hirabai jehangir',
#  'hospital february',
#  'aintree university hospitals nhs foundation trust british public sector healthcare provider responsible managing aintree university hospital fazakerley liverpool england',
#  'november aintree hospitals national health service trust',
#  'nhs foundation trust name aintree university hospitals nhs foundation trust',
#  'august',
#  'university hospitals nhs trust form liverpool university hospitals nhs foundation trust',
#  'lincoln community health center lchc outpatient primary care facility',
#  'durham north carolina',
#  'lincoln hospital lchc',
#  'wide range health services',
#  'adult medicine pediatrics dental social work mental health services family care nursing outreach home prenatal family planning services',
#  'available center cooperation durham county health department',
#  'blackstone hotel historic foot story hotel corner michigan avenue balbo',
#  'michigan',
#  'historic district loop community area chicago illinois',
#  'national register historic places',
#  'famous hosting celebrity guests',
#  'numerous u presidents',
#  'hotel presidents',
#  'century',
#  'nature boy song',
#  'first recorded american jazz singer nat king cole',
#  'march single capitol records',
#  'album nat king cole story',
#  'eden ahbez tribute bill pester',
#  'naturmensch',
#  'lebensreform philosophies',
#  'ahbez lyrics song relate los angeles based group',
#  'nature boys',
#  'proto hippies ahbez member nature boy',
#  'american federation musicians afm ban',
#  'top billboard music charts',
#  'million copies',
#  'cole solo career',
#  'white music market nature boy subject lawsuits',
#  'yiddish composer herman yablokoff',
#  'plagiarized song shvayg mayn harts',
#  'eventually ahbez yablokoff settled court song',
#  'grammy hall fame award',
#  'cole success rival record companies',
#  'cover versions',
#  'nature boy artists',
#  'frank sinatra sarah vaughan',
#  'many artists',
#  'song',
#  'tony bennett lady gaga',
#  'collaborative album cheek cheek',
#  'numerous films',
#  'boy green hair',
#  'mr ripley musical moulin rouge singer david bowie',
#  'version',
#  'directorate general immigration passports dgip department control interior secretary pakistan responsible deal issues',
#  'pakistani citizenship passports visas',
#  'business association stanford entrepreneurial students',
#  'student group stanford university',
#  'business entrepreneurial activities',
#  'world bases mission',
#  'worlds entrepreneurship academia industry bases',
#  'flagship k challenge entrepreneurial thought leaders seminar svi hackspace e bootcamp freshman battalion bases',
#  'group five stanford engineers organization works partnership silicon valley venture capitalists law firms',
#  'variety entrepreneurial services',
#  'stanford students',
#  'u house financial services subcommittee domestic international monetary policy trade technology subcommittee house committee financial services',
#  'th congress',
#  'two subcommittees domestic monetary policy technology international monetary policy trade',
#  'constitution south africa',
#  'basic political freedoms',
#  'however many incidents political repression',
#  'future repression violation constitution leading analysts',
#  'civil society organisations popular movements',
#  'new climate political repression',
#  'political tolerance',
#  'repression',
#  'jacob zuma presidency analysts',
#  'increase repression influence security cluster jacob zuma presidency',
#  'zuma',
#  'coercive capacity state focused building state based fear',
#  'repression',
#  'affected poor people organisations',
#  'poor people',
#  'media serious concern',
#  'police brutality',
#  'south africa',
#  'south africa brutal police state',
#  'greg marinovich police acting impunity political masters acting impunity',
#  'south africa',
#  'political clout amnesty international',
#  'serious concerns brutality',
#  'torture extrajudicial killings',
#  'police south africa ronnie kasrils',
#  'descent police state depravity jacob zuma',
#  'south africa police stations',
#  'country',
#  'serious problem',
#  'responsible repression grassroots activists bishop rubin phillip',
#  'country',
#  'light democratic dawn',
#  'non profit student',
#  'students',
#  'bishop',
#  'src responsible number services',
#  'students',
#  'variety academic non academic clubs students',
#  'directly involved bishop life',
#  'also responsible several publications',
#  'responsible organizing events campus ranging orientation week election valedictorian',
#  'socialist environment resources association sera',
#  'independent environmental association',
#  'uk labour party socialist society time',
#  'name sera labour environment campaign',
#  'rather full name sera campaigns',
#  'progressive environmental policies',
#  'labour party sera co chairs lisa trickett ken penton sera members',
#  'local groups',
#  'country good links',
#  'uk labour party',
#  'many environmental groups',
#  'sera',
#  'policy development transport energy water waste biodiversity sera national executive numbers',
#  'people',
#  'annual general meeting',
#  'november executive members',
#  'alan whitehead daniel zeichner alex sobel sandy martin leonie cooper huw',
#  'davies',
#  'lyon france',
#  'capacity arena people',
#  'miangul abdul haq jahanzeb kidney hospital mjkh',
#  'hospital situated manglawar swat',
#  'jahan zeb',
#  'swat second w li swat bed hospital project punjab hospitals trust',
#  'kanal unit',
#  'officials hospital bed urology bed nephrology units',
#  'sorts services',
#  'free surgeries',
#  'three state art operation',
#  'renal diseases',
#  'average dialysis treatments',
#  'facility',
#  'hdu',
#  'seriously ill patients',
#  'ministry environment urbanisation climate change',
#  'evre',
#  'ehircilik',
#  'klim de ikli bakanl government ministry republic turkey responsible environment public',
#  'urban planning turkey ministry',
#  'murat kurum',
#  'hazara cuisine hazaragi cuisine hazaragi',
#  'food cuisine hazara people',
#  'western pakistan',
#  'balochistan province food hazara people',
#  'central asian south asian cuisines shares similarities',
#  'regional cuisines',
#  'afghanistan central asia',
#  'however certain dishes culinary methods styles',
#  'unique hazara people hazara people',
#  'dining etiquette hazaragi culture customary',
#  'special food guests',
#  'best seats meal times hazaras',
#  'food hands',
#  'cutlery dining utensils forks knives spoons diet hazara people',
#  'intake high protein foods',
#  'dairy products',
#  'large amounts',
#  'oil cooking typical hazara meal dining course',
#  'one type food dish',
#  'rather wide selection',
#  'large formal gatherings presence guests variety foods',
#  'household hazara cuisine',
#  'three main types breads',
#  'hazara people',
#  'bread',
#  'oven known tandoor nan buta bread thick brick sized bread rice',
#  'less frequent rural hazara cuisine due expense tea popular beverage',
#  'hazara people fruits vegetables',
#  'san diego state university college education',
#  'teacher education training programs',
#  'san diego state university sdsu',
#  'undergraduate programs',
#  'credentials degree holders master degrees ed ph doctoral degrees college',
#  'undergraduate graduate students',
#  'professional educators',
#  'careers administrators teachers professors school psychologists',
#  'resource training specialists',
#  'educational support personnel',
#  'polycystic kidney disease',
#  'autosomal dominant protein humans',
#  'pkd gene polycystic kidney disease adpkd life',
#  'hereditary disorder characterized development fluid',
#  'cyst formation expansion kidney',
#  'autosomal dominant disease common hereditary disorders rate occurrence',
#  'general health questionnaire ghq psychometric screening tool',
#  'common psychiatric conditions',
#  'validated least two languages',
#  'addition english',
#  'spanish persian latter',
#  'different fields generations',
#  'ghq beneficial high tech systems personnel questionnaire',
#  'number questions',
#  'four point likert scale responses versions questions',
#  'valid use adults',
#  'bangur institute neurosciences',
#  'bangur institute neurology abbreviated bin government',
#  'apex superspeciality institute hospital',
#  'west bengal institute',
#  'ipgmer sskm hospital institute',
#  'west bengal university health science government',
#  'neurological institute training centre field neuroscience west bengal patients',
#  'various hospitals',
#  'west bengal adjoining states hospital research activities',
#  'studies strokes cognitive neuroscience movement disorders',
#  'epilepsy neuromuscular conditions',
#  'myasthenia developmental disorders brain wilson disease electrophysiology botulinium toxin neurogenetics',
#  'concacaf u tournament',
#  'north american international association football tournament',
#  'determined fifa u world championship',
#  'concacaf region edition competition',
#  'cuba',
#  'transitional bilingual education',
#  'bilingual education students',
#  'fluency native language',
#  'fluency second language fluency',
#  'linguistic fluency',
#  'well literacy',
#  'reading',
#  'contrast',
#  'total immersion bilingual education students',
#  'second language transitional bilingual education',
#  'commonly implemented public schools',
#  'united states application transitional bilingual education united states',
#  'effort',
#  'passage bilingual education act goal transitional bilingual education',
#  'transition student english classroom',
#  'quickly possible bilingual teacher',
#  'children',
#  'math science social studies',
#  'native language transition',
#  'necessary compete peers',
#  'subject areas',
#  'kindergarten',
#  'grade',
#  'six seven english second language courses',
#  'provide supplemental instruction transitional bilingual education programs',
#  'two categories',
#  'late exit early exit programs',
#  'strong support students',
#  'native language',
#  'rapidly diminished late exit programs hand',
#  'strong support primary language fundamental difference',
#  'two models length program',
#  'japan air lines flight scheduled passenger flight november plane new douglas',
#  'dc',
#  'shiga flying tokyo international airport haneda san francisco international airport sfo',
#  'heavy fog factors',
#  'captain kohei asoh',
#  'plane',
#  'coyote point shallow waters',
#  'san francisco bay',
#  'two half miles short runway people board survived accident',
#  'injuries',
#  'yankin education college burmese educational college',
#  'basic essential role teacher',
#  'two years',
#  'primary secondary teachers',
#  'new training program fresh graduate',
#  'cobol',
#  'ec location',
#  'third division football tournament third division maldives football league system',
#  'football association',
#  'new structure third division football tournament',
#  'puerto rico science technology research trust private non profit organization',
#  'encourage',
#  'promote innovation transfer commercialization technology creation jobs technology sector',
#  'san juan puerto rico trust',
#  'puerto',
#  'new small businesses technology based business plan trust',
#  'inventors',
#  'patents',
#  'director puerto rico science technology research transfer office david gulley goal transfer office help',
#  'rico',
#  'science',
#  'special economic zone sez area business trade laws',
#  'different rest country sezs',
#  'country national borders',
#  'increasing trade balance employment',
#  'investment job creation effective administration encourage businesses',
#  'zone financial policies',
#  'policies',
#  'taxation trading quotas',
#  'customs labour regulations',
#  'companies',
#  'tax holidays',
#  'zone',
#  'granted period lower taxation creation special economic zones host country',
#  'desire',
#  'foreign direct investment fdi benefits company',
#  'special economic zone',
#  'trade goods lower price',
#  'globally competitive countries zones',
#  'little labor camps workers',
#  'fundamental labor rights',
#  'athens technical college athens tech unit technical college system',
#  'georgia',
#  'athens georgia',
#  'athens area vocational technical school school',
#  'athens area technical institute',
#  'current name',
#  'certificates',
#  'associate degrees business health technical manufacturing related fields school administrative offices main campus located athens satellite campuses',
#  'elberton monroe georgia campus greensboro closed addition school',
#  'several educational centers school',
#  'ten county service area',
#  'street king',
#  'energy drink',
#  'american rapper curtis cent jackson pure growth partners ceo chris clarke',
#  'australian research institute environment sustainability aries',
#  'australian profit research centre macquarie university macquarie park',
#  'new south wales',
#  'australian government conduct research supports',
#  'sustainable lifestyles',
#  'australian research institute education sustainability first director program daniella tilbury',
#  'phongolo nature reserve ezemvelo kzn wildlife reserve maputaland',
#  'natal south africa reserve',
#  'extent reserve co operative conservation project',
#  'private landowners',
#  'tribal communities government conservation services',
#  'form heart',
#  'large ecological socio',
#  'economically viable big five reserve home impressive collection wildlife vegetation addition',
#  'herds',
#  'also hyenas buffalos rhinos',
#  'zebras',
#  'giraffes impalas',
#  'market street historic district national historic district located potsdam st lawrence county new york district',
#  'buildings',
#  'district encompasses extant th century commercial core village',
#  'national register historic places',
#  'capitol skyline hotel hotel',
#  'united states capitol capitol hill washington c',
#  'morris lapidus hotel',
#  'november skyline inn part best western chain hotel',
#  'covid pandemic used shelter',
#  'medically vulnerable residents',
#  'history science peer',
#  'academic journal',
#  'history science medicine technology editor chief lissa l roberts university twente',
#  'published sage publications',
#  'economic party partito economico',
#  'italian political party',
#  'turin group dealers',
#  'worried red biennium group',
#  'politics',
#  'economic science',
#  'strongest constituencies',
#  'larger cities',
#  'northern italy',
#  'benefits alliance',
#  'agrarian party general election',
#  'vote seats support',
#  'election pe',
#  'vote seats',
#  'agrarian party',
#  'wild wing restaurants canadian franchised restaurant chain',
#  'chicken wings',
#  'foods',
#  'related products',
#  'chester f phelps wildlife management area',
#  'f',
#  'wildlife management area',
#  'acre km wildlife management area',
#  'fauquier culpeper counties virginia',
#  'acres',
#  'km open land',
#  'forests property terrain',
#  'low shallow steepest land',
#  'rappahannock river forms',
#  'center forests',
#  'property contain pine hardwood area',
#  'seasonal hunting deer turkey small game waterfowl',
#  'range sighting rifles available fishing',
#  'opportunities',
#  'sunfish carp bass channel catfish phelps pond rappahannock river kelly ford',
#  'smallmouth bass largemouth bass rock bass sunfish carp channel catfish suckers',
#  'kayak boat ramp',
#  'ford permissible activities',
#  'primitive camping chester f phelps wildlife management area',
#  'access persons years',
#  'age',
#  'valid hunting fishing permit',
#  'access permit',
#  'naval sports complex multi use stadium islamabad',
#  'football games',
#  'people',
#  'pydah college engineering technology pcet',
#  'technical college gambheeram boyapalem visakhapatnam andhra pradesh india pcet affiliated jawaharlal',
#  'technological university kakinada jntuk india council technical education approval',
#  'hca florida pasadena hospital',
#  'pasadena hospital hospital',
#  'st petersburg florida',
#  'economic history china',
#  'china economic history',
#  'dynasty economic history',
#  'china economic history republic china period controlled chinese mainland economic history republic china period',
#  'economic history',
#  'taiwan modern history economic history',
#  'china',
#  'present economic history people',
#  'china',
#  'sina sports chinese digital sports media platform',
#  'live sporting events',
#  'news discussion forums related sports content',
#  'chinese communities',
#  'world subsidiary chinese internet company sina com',
#  'china first online sports platform platform',
#  'online website mobile website mobile app available chinese language mobile available ios android devices platform',
#  'multiple verified sina weibo accounts',
#  'sinasports sinasportsvideo others',
#  'million weibo followers',
#  'gyeongdong market korean sometimes kyungdong market',
#  'dongdaemun district',
#  'one largest herbal medicine ginseng markets south korea',
#  'establishment market supplies percent nation herbal medicine',
#  'related shops oriental medicine clinics area gyeongdong market',
#  'wholesale retail markets',
#  'agricultural products',
#  'fish square meters',
#  'size seoul sangam world cup stadium',
#  'subway',
#  'maac men soccer tournament th edition maac men soccer tournament tournament',
#  'metro atlantic athletic conference champion',
#  'guaranteed representative ncaa division men soccer championship',
#  'champions rider broncs',
#  'title',
#  'regular season champions quinnipiac championship game title rider',
#  'fourth overall maac championship additionally rider',
#  'first school',
#  'marist repeat maac tournament champions',
#  'university',
#  'semifinals',
#  'final tournament',
#  'higher seeds',
#  'mobil sportscar grand prix sports car race',
#  'international motor sports association imsa',
#  'canadian tire motorsport park',
#  'bowmanville ontario',
#  'july race',
#  'weathertech sportscar championship event',
#  'st imsa sanctioned sports car race',
#  'facility',
#  'feminist economics critical study economics economies',
#  'gender aware inclusive economic inquiry policy analysis',
#  'feminist economic researchers',
#  'academics activists policy theorists',
#  'much feminist economic research',
#  'topics',
#  'neglected field care work intimate partner violence economic theories',
#  'better incorporation gendered effects interactions',
#  'unpaid sectors economies',
#  'feminist scholars',
#  'new forms data collection measurement gender empowerment measure gem gender aware theories capabilities',
#  'feminist economics',
#  'goal',
#  'well children',
#  'local national transnational communities',
#  'feminist economists',
#  'traditional economics',
#  'questioning extent',
#  'exclusive attention masculine associated topics',
#  'masculine associated assumptions',
#  'economics',
#  'masculine associated ideas',
#  'feminist economists',
#  'fuller exploration economic life',
#  'culturally feminine topics family economics',
#  'importance connections concreteness emotion',
#  'economic phenomena',
#  'many scholars',
#  'ester boserup marianne',
#  'drucilla k barker julie nelson marilyn',
#  'nancy folbre diane elson barbara bergmann ailsa mckay',
#  'feminist economics waring book women',
#  'often regarded founding document discipline feminist economics',
#  'economics generate book article publication opportunities practitioners',
#  'abc wide world entertainment',
#  'television block programs',
#  'abc television network',
#  'premiered january',
#  'long running broadcast abc wide world sports',
#  'wide world mystery broadcast',
#  'jackson f kimball state recreation site seasonal state park southern oregon park',
#  'maintained oregon parks recreation department',
#  'approximately miles km southeast crater lake national park miles km north fort klamath park',
#  'covers acres',
#  'headwaters wood river',
#  'makerere university college health sciences',
#  'one colleges',
#  'makerere university east africa oldest university college',
#  'consolidating training',
#  'medicine dentistry pharmacy',
#  'schools school medicine school public health school',
#  'biomedical sciences school dentistry school',
#  'health sciences college',
#  'health sciences',
#  'masters',
#  'international student festival trondheim norway',
#  'allegedly world largest student festival thematic emphasis',
#  'approximately students world',
#  'festival themes change festival',
#  'always related social political topics international relevance stated purpose isfit meeting place discussion debate arena ideas born friendships',
#  'valuable lessons',
#  'festival',
#  'inspiration',
#  'international cooperation',
#  'students',
#  'non profit festival isfit participants',
#  'part',
#  'different workshops',
#  'festival theme',
#  'several lectures thematic meetings',
#  'well known international speakers share views',
#  'others',
#  'arranged trondheim norway',
#  'students',
#  'voluntarily order',
#  'big ten conference baseball tournament',
#  'illinois field campus university illinois urbana champaign champaign illinois',
#  'six teams regular season',
#  'double elimination tournament twenty fourth annual tournament',
#  'big ten conference determine league champion ohio state seventh tournament championship',
#  'big ten conference automatic bid ncaa division baseball tournament',
#  'columbia hospital women',
#  'former hospital',
#  'washington c',
#  'health care facility wives',
#  'civil war soldiers',
#  'thomas circle',
#  'location l street nw west',
#  'private non profit hospital president dwight eisenhower',
#  'legislation',
#  'board directors facility',
#  'closed building',
#  'converted condominium columbia residences',
#  'people',
#  'columbia hospital women duke ellington marion christopher barry al gore andrew schwartz katherine heigl michael dominic julie nixon eisenhower george ross wes moore',
#  'new market presbyterian church historic building located heart new market alabama years church pillar community late gothic revival style church',
#  'added national register historic places',
#  'skarvan',
#  'national park norwegian skarvan',
#  'roltdalen',
#  'tr ndelag county norway park located municipalities selbu tydal mer ker stj',
#  'rdal far border sweden east square kilometre sq mi park',
#  'borders',
#  'str sj',
#  'en prest yan nature reserve park',
#  'large spruce forested area roltdalen valley largest roadless mountain valley southern tr ndelag county',
#  'skarvan mountainous region',
#  'typical tr ndelag region cultural natural history',
#  'skarvan mountains',
#  'ruten fongen notable mountainous area region trondhjems',
#  'maintains network',
#  'trails',
#  'roltdalen trail network',
#  'nord tr ndelag tourist association trails',
#  'sylan area',
#  'federal office bundeswehr equipment information technology service support',
#  'f r ausr stung informationstechnik',
#  'und nutzung der',
#  'baainbw german government agency',
#  'german armed forces',
#  'modern weapon systems',
#  'cost efficiency',
#  'responsible developing assessing procuring weapon systems',
#  'merging bundesamt',
#  'f r wehrtechnik',
#  'beschaffung bwb',
#  'f r informationsmanagement und informationstechnik amtbw goal',
#  'synergies',
#  'federal ministry defence germany',
#  'bonn berlin',
#  'capital city wales',
#  'significant service centre economic driver',
#  'wider south east wales economy city adjoining vale glamorgan',
#  'disproportionately high share economic output wales cardiff travel work area',
#  'based version',
#  'glamorgan th century economy cardiff',
#  'coal exportation steel production cardiff port',
#  'world important coal port',
#  'london liverpool',
#  'cardiff centre white collar professions city',
#  'principally retail finance media tourism sectors',
#  'major regeneration',
#  'late th century particularly cardiff city centre cardiff bay',
#  'nordic tournament first edition',
#  'place',
#  'lahti kuopio falun',
#  'oslo',
#  'nutrients open access peer',
#  'reviews',
#  'nutrition',
#  'mdpi',
#  'manuscripts',
#  'mediocre quality importance current editors chief maria luz fernandez lluis serra majem journal associated nutrition society australia nutrition society new zealand spanish nutrition foundation spanish nutrition society others',
#  'referendum health insurance',
#  'liechtenstein january proposal',
#  'voters',
#  'hearts',
#  'women',
#  'championship northwest territories',
#  'january yellowknife curling centre yellowknife',
#  'northwest territories',
#  'first year winner',
#  'northwest territories scotties',
#  'directly scotties tournament hearts',
#  'two northwest territories teams',
#  'nwt yukon scotties tournament hearts',
#  'right play',
#  'national championship',
#  'two rinks',
#  'time territorial champion',
#  'ann mckellar gillis yellowknife',
#  'northwest territories scotties tournament hearts',
#  'aurora mental health recovery private nonprofit community mental health center aurora colorado',
#  'originally named aurora mental health center organization',
#  'rebrand january center',
#  'individuals',
#  'federal poverty level uninsured services',
#  'programs',
#  'centers',
#  'residential facilities sites',
#  'criminal justice settings homes',
#  'emergencies crises',
#  'crisis center crisis stabilization unit mobile crisis response community',
#  'australian rules football sport',
#  'sixty countries',
#  'world list',
#  ...]

# %%
train_phrases
# Out:
# [['cherno sports complex football training ground',
#   'asparuhovo district varna bulgaria cherno sports complex home ground cherno ii academy cherno stadium located asparuhov bridge capacity spectators stadium',
#   'korabostroitel',
#   'cherno sports complex',
#   'one main pitch',
#   'also junior training matches',
#   'one training pitch synthetic grass',
#   'junior team training matches'],
#  ['nepal',
#   'part guna group nepalese conglomerate companies',
#   'operations',
#   'operations simrik airlines airline',
#   'operations',
#   'operations',
#   'back initial airline company'],
#  ['batang',
#   'national park malay taman negara batang',
#   'national park located sri aman division',
#   'malaysia located lubok',
#   'kilometers east kuching',
#   'park',
#   'area square kilometres',
#   'mi',
#   'extensive tropical rainforest number rare protected animals',
#   'square kilometer artificial lake',
#   'created batang',
#   'hydroelectric reservoir park',
#   'increasingly popular locals tourists',
#   'boat traditional boat',
#   'longboat water main method transportation area ride',
#   'approximately minutes',
#   'batang',
#   'national park headquarters',
#   'dipterocarp forests',
#   'home orang utan gibbons hornbills lake',
#   'beautiful environment',
#   'sense peace tranquillity',
#   'local inhabitants',
#   'mostly iban tours',
#   'iban longhouses',
#   'diversion',
#   'national park',
#   'strong steps',
#   'local communities',
#   'management communities',
#   'kooperasi serbaguna',
#   'ulu batang',
#   'park'],
#  ['tin hau food square new food colony',
#   'hong kong name',
#   'located tin hau station fortress hill station electric road wing hing street tsing fung street',
#   'restaurants',
#   'many different styles cuisine',
#   'chinese western thai japanese korean'],
#  ['molecular biology small nucleolar',
#   'rna z snord',
#   'u',
#   'rna ncrna molecule functions',
#   'modification small nuclear rnas snrnas type',
#   'rna',
#   'usually located nucleolus eukaryotic cell major site snrna biogenesis',
#   'small nucleolar rna snorna',
#   'guide',
#   'rna snorna z snord',
#   'snornas',
#   'conserved sequence motifs',
#   'site specific methylation substrate rnas plant',
#   'relative matched noncancerous lung tissues'],
#  ['straume nature reserve norwegian straume',
#   'b municipality nordland county norway nature reserve',
#   'south village straume west side island lang ya',
#   'two lakes',
#   'f revatnet saltvatnet shallow inlet',
#   'skj risen',
#   'area hectares',
#   'hectares acres water area',
#   'central parts',
#   'especially rich specialized bird population nature reserve',
#   'december norwegian county road',
#   'two halves nature reserve'],
#  ['dubai science park dsp',
#   'home companies',
#   'multinational corporations',
#   'people region',
#   'position',
#   'united arab emirates destination research development',
#   'creativity innovation areas',
#   'al barsha',
#   'zayed sheikh',
#   'route f mall emirates',
#   'approximately minutes dubai international airport company subsidiary government dubai holding company dubai holding'],
#  ['corcovado national park spanish parque nacional corcovado national park osa peninsula',
#   'osa canton located southwestern regions',
#   'part',
#   'october occupies area square kilometres sq mi currently largest park costa rica',
#   'third osa peninsula park largest primary forest american pacific coastline',
#   'one remaining sizable areas',
#   'tropical forests',
#   'world',
#   'taken place lowland areas',
#   'easy accessibility presence',
#   'abundant economically valuable trees habitats',
#   'diverse vegetation',
#   'biodiversity',
#   'originally rich lowland forests',
#   'small area',
#   'original natural biodiversity'],
#  ['nature park flores portuguese parque natural das flores',
#   'nature park',
#   'intention better managing protected areas island flores',
#   'secretaria regional ambiente',
#   'e mar regional secretariate environment',
#   'several ecosystems environmentally distinct nature reserve',
#   'three principal areas',
#   'calderas funda rasa mountain region',
#   'morro alto pico da islet',
#   'vaz addition',
#   'several protected areas'],
#  ['chinese aristocrat cuisine chinese pinyin gu nf c traces origin ming qing dynasties',
#   'imperial officials',
#   'beijing',
#   'private chefs',
#   'unique breed',
#   'chinese aristocrat cuisine',
#   'private cuisine current chinese aristocrat cuisine mixture shandong cuisine huaiyang cuisine cantonese cuisine beijing capital last three chinese dynasties chinese aristocrat cuisine',
#   'beijing',
#   'nine varieties',
#   'chinese aristocrat cuisine'],
#  ['cheese heroin based recreational drug',
#   'attention media',
#   'united states string deaths',
#   'adolescents dallas drug use',
#   'older people teenagers',
#   'period drug',
#   'first discovered cheese combination drugs',
#   'combining heroin',
#   'tablets',
#   'cold medication tylenol pm',
#   'paracetamol active ingredient tylenol antihistamine',
#   'active ingredient benadryl cheese samples',
#   'north dallas',
#   'heroin contrast',
#   'black tar heroin users',
#   'powder insufflation',
#   'rather intravenous injection mixture',
#   'also known tylenol smack analogy tylenol codeine series',
#   'due high concentrations',
#   'opiate substances',
#   'relative diamorphine content drug abuse overdose cheese dangerous pure form opiate overdoses emergency personnel',
#   'overdose effects component drug',
#   'contents concentrations component',
#   'batches',
#   'completion toxicology report',
#   'treatment wait effects drugs',
#   'overdose manifest acetaminophen content drug',
#   'severe irreversible damage liver',
#   'high doses',
#   'high doses',
#   'capable producing acute liver failure death',
#   'hours patients',
#   'acute phase toxicity',
#   'dialysis',
#   'transplant',
#   'due many methods preparation user',
#   'batch',
#   'safe dose dose last batch',
#   'toxic effects',
#   'lethal effects'],
#  ['armchair science british monthly journal topical popular science articles',
#   'publication wartime paper shortages',
#   'brooklands professor low issue',
#   'wonders night sky flowers',
#   'bad cheese bad meat noise',
#   'later reduced sixpence publisher gale polden ltd london',
#   'splitting atom chemical identification vitamin c finishing dutch dam',
#   'zuyder zee developments television',
#   'looking future asked whales',
#   'discussed possibility',
#   'stereoscopic cinema',
#   'biofuels power sea editor stuart macrae',
#   'weapons war effort part',
#   'md',
#   'toyshop'],
#  ['plus markets group uk electronic stock exchange',
#   'financial instruments',
#   'regulated market multilateral trading facility plus market group holding company',
#   'stock exchange',
#   'sx',
#   'derivatives',
#   'dx',
#   'technology',
#   'tx',
#   'cash trading',
#   'derivatives technology services group',
#   'financial trouble',
#   'ways sell business exchange',
#   'listed companies',
#   'exchange license',
#   'icap technology division',
#   'gmex group',
#   'trading solutions',
#   'markets',
#   'icap',
#   'icap securities derivatives'],
#  ['joint economic development district jedd arrangement ohio one municipalities township',
#   'township land commercial industrial purposes benefit municipality',
#   'portion taxes',
#   'jedd',
#   'annex benefits township',
#   'prime development land',
#   'property taxes',
#   'portion income tax',
#   'water municipality',
#   'may otherwise ohio',
#   'general assembly',
#   'legislation',
#   'local communities',
#   'create jedds jedds',
#   'summit county akron annexing parts neighboring townships',
#   'bad relations townships',
#   'economically mayor plusquellic',
#   'idea jedd way',
#   'city tax base',
#   'fight neighbors',
#   'new legislation state initially summit county',
#   'jedds',
#   'rest state akron',
#   'jedds springfield coventry copley',
#   'later conjunction fairlawn',
#   'jedd bath township',
#   'communities summit county rest state formed jedds',
#   'jedd municipality township work',
#   'details taxes',
#   'shared annexation prohibitions water rates communities vote agreement issue',
#   'community jedd approved jedd',
#   'city columbus franklin county ohio',
#   'three jurisdictions pickaway county purpose',
#   'infrastructure available aid business development',
#   'due construction intermodal facility',
#   'norfolk southern railway presence',
#   'provision sanitary sewer water roadway connectivity infrastructure',
#   'necessary new business location rickenbacker area',
#   'almost square feet distribution space',
#   'rickenbacker area',
#   'almost direct indirect jobs partners',
#   'greater columbus chamber commerce competecolumbus franklin county',
#   'south bloomfield ashville jedds',
#   'agreements',
#   'falls olmsted township cuyahoga county ohio city dayton butler township montgomery county effective january city dayton miami township montgomery county',
#   'economic development',
#   'dayton wright brothers airport city milford union township clermont county',
#   'income tax ivy pointe business park city middletown liberty township butler county economic expansion acres km commercial development liberty interchange addition increased visibility'],
#  ['tha tian market thai rtgs talat tha tian',
#   'l',
#   'n one famous historical ordinary community market phra nakhon district bangkok thailand rattanakosin island',
#   'grand palace',
#   'next wat pho chao phraya river',
#   'tian pier next market',
#   'culture food market',
#   'dried salted seafood products wholesale products',
#   'dailynews river',
#   'tha',
#   'tian market biggest trading center chao phraya river',
#   'th th century rattanakosin era river'],
#  ['republic uzbekistan semi presidential constitutional republic',
#   'president uzbekistan head state executive power',
#   'government prime minister uzbekistan legislative power',
#   'two chambers oliy majlis senate legislative chamber judicial branch judiciary',
#   'supreme court constitutional court',
#   'judicial power movement',
#   'economic reform uzbekistan matched movement',
#   'political reform government uzbekistan',
#   'instead tightened grip',
#   'independence september',
#   'increasingly opposition groups',
#   'names',
#   'institutions government',
#   'similar existed breakup',
#   'soviet union government',
#   'restraint public assembly opposition parties',
#   'stability gradual approach change transitional period',
#   'conflict chaos',
#   'former republics convincingly neighbouring tajikistan approach',
#   'credence',
#   'large share uzbekistan population',
#   'position',
#   'trappings institutional change',
#   'independence',
#   'resistance acceptance institutional changes',
#   'democratic reform',
#   'whatever initial movement',
#   'democracy',
#   'uzbekistan',
#   'independence',
#   'inertia',
#   'remaining soviet style strong centralized leadership'],
#  ['hospital infanta',
#   'ospi tal fanta fi northern terminus line madrid metro serving hospital universitario infanta',
#   'princess sof university hospital located fare zone b'],
#  ['historical significance',
#   'century',
#   'later family residence property converted hotel',
#   'accommodation restaurant facilities',
#   'special events',
#   'particularly weddings cinema museum london',
#   'home movie footage hotel'],
#  ['new zealand local elections',
#   'nga p',
#   'rohe triennial elections',
#   'new zealand',
#   'saturday october voting',
#   'postal vote',
#   'september'],
#  ['rod smith canadian sports commentator host tsn sportscentre',
#   'cfl tsn',
#   'kate beirness',
#   'play play announcer cfl'],
#  ['ncaa women soccer',
#   'fourth annual single elimination tournament',
#   'national champion ncaa women',
#   'soccer championship game',
#   'george mason stadium fairfax virginia november george mason',
#   'champion',
#   'north carolina final win first national title patriots',
#   'hank leung',
#   'championship north carolina outstanding player pam baughman george mason outstanding defensive player',
#   'betsy drambour george mason tournament team',
#   'year',
#   'leading scorer tournament lisa gmitter george mason goals'],
#  ['steppin movie american musical comedy film film stars',
#   'wesley jonathan chrystee pharris',
#   'michael taliferro'],
#  ['galati fresh market small chain supermarkets toronto',
#   'galati brothers',
#   'one location',
#   'leslie street south steeles',
#   'former locations',
#   'jane street north york',
#   'steeles',
#   'west pacific fresh food market',
#   'hwy dixie rd',
#   'yi xing chinese supermarket shoppers',
#   'drug mart wilson avenue keele street',
#   'galati brothers',
#   'chinese supermarket',
#   'westway etobicoke',
#   'one first close location shoppers'],
#  ['patlabor movie',
#   'japanese animated science fiction film',
#   'mamoru oshii',
#   'kazunori original story headgear',
#   'bandai visual tohokushinsha',
#   'g tatsunoko part patlabor series'],
#  ['american video entertainment inc american video game company',
#   'san jose california company',
#   'unlicensed video games nintendo entertainment system company',
#   'two games dudes attitude',
#   'treasure island published games'],
#  ['houston journal health law policy biannual open access peer',
#   'student run law journal',
#   'issues health law policy',
#   'affiliated health law policy institute university houston law center united states year fall issue dedicated symposium organized journal',
#   'topic',
#   'articles variety topics'],
#  ['portland public market public market portland oregon united states',
#   'widely advertised cost million million controversial ambitious intended replace carroll public market',
#   'southwest fifth yamhill streets portland public market',
#   'never popular financial trouble',
#   'heavy corruption graft mayor george luis baker city commissioner john mann',
#   'others',
#   'clearly heavily involved recall effort',
#   'signatures',
#   'petition mysteriously stolen break house',
#   'two leaders',
#   'bombed baker',
#   'market corruption charges days recall vote',
#   'failed remove office',
#   'eleven story towers',
#   'three blocks long features',
#   'gas station',
#   'parking seat auditorium',
#   'tenants',
#   'finally closing architect',
#   'building',
#   'u',
#   'navy',
#   'oregon journal',
#   'newspaper offices operations plant',
#   'publishing years paper vacated building',
#   'unused purchased city portland building',
#   'year',
#   'way expansion harbor drive',
#   'tom mccall waterfront park',
#   'currently permanent public market city',
#   'plans',
#   'james beard public market'],
#  ['department industry science energy resources department australian government responsible consolidating government efforts',
#   'economic growth productivity competitiveness',
#   'industry energy resources science department',
#   'department industry innovation science february superseded department industry science resources department climate change energy environment water july head department time dissolution secretary david',
#   'minister science day'],
#  ['sanbusco market center sanbusco center historic commercial building santa fe new mexico sanbusco center',
#   'originally santa fe railroad commercial center',
#   'santa fe business company',
#   'site',
#   'national historic status time',
#   'sanbusco center',
#   'industrial style',
#   'historic old adobe structures unique design preserved renovation sanbusco center shops restaurants offices site',
#   'three world class restaurants law offices',
#   'retail establishments',
#   'pen shop',
#   'state lawmakers',
#   'documentary photography original building historic text references',
#   'new mexico'],
#  ['annual fashion show',
#   'promote',
#   'market goods',
#   'high profile settings',
#   'world leading fashion models',
#   'current victoria secret angels',
#   'heidi klum adriana lima alessandra ambrosio karolina kurkova selita',
#   'izabel goulart marisa miller',
#   'miranda kerr th fashion show',
#   'new angels',
#   'heidi klum spice girls',
#   'hosted heidi klum'],
#  ['basic food flavors inc private company',
#   'north las vegas nevada united states',
#   'soy',
#   'varieties',
#   'hvp',
#   'various products',
#   'chips',
#   'dressings',
#   'snack foods private company',
#   'financial information',
#   'million march united states food drug administration',
#   'investigation customer basic food flavors',
#   'salmonella',
#   'one production lot hvp',
#   'ready cook hvp products',
#   'canada recall resulted products',
#   'grocery shelves company',
#   'nevada pomona california',
#   'california economic regulations'],
#  ['hospital st lawrence',
#   'st lawrence hospital hospice st lawrence free chapel hospice st lawrence st james medieval house lepers',
#   'town',
#   'nantwich cheshire england located west town welsh row',
#   'parish acton st lawrence',
#   'hospital infirm poor dissolved hospital land property',
#   'wright family',
#   'one buildings',
#   'dwellings'],
#  ['algiers houari boumedienne airport algeria',
#   'june airline merged khalifa airways company'],
#  ['saxion university',
#   'sciences',
#   'hogeschool saxion dutch university',
#   'sciences',
#   'health digital media students',
#   'bachelor master education research',
#   'focused living technology roots saxion university',
#   'merger two educational institutions hogeschool enschede hogeschool ijselland',
#   'way saxion university present form merger',
#   'saxion',
#   'strong position',
#   'higher education',
#   'saxion university',
#   'important center expertise regional national international level'],
#  ['hospital god greatham county durham',
#   'bishop durham robert de stichell',
#   'poor people',
#   'house entertainment gentlemen',
#   'poor reforms original mission',
#   'visiting services patients',
#   'wheatley',
#   'outside hospital'],
#  ['dr ram manohar lohia hospital',
#   'formerly known willingdon hospital central government hospital new delhi india atal bihari vajpayee institute medical sciences',
#   'hospital',
#   'undergraduate postgraduate courses hospital',
#   'beds',
#   'british raj government staff',
#   'newly independent india control hospital transferred central government department health family welfare',
#   'dr ram manohar lohia important proponent socialist ideology india hospital spread acres',
#   'land',
#   'well positioned location',
#   'nursing home central government health scheme beneficiaries extensive subspecialty care annually hospital',
#   'services million patients opd cases',
#   'patients',
#   'emergency patients',
#   'hospital conducts',
#   'ct scans mri scans x ray cases million laboratory tests ultrasound',
#   'major minor operations',
#   'year hospital',
#   'separate cghs opds cghs beneficiaries hospital',
#   'number beds',
#   'safdarjung hospital'],
#  ['john race', 'tomlinson'],
#  ['fundy national park',
#   'kouchibouguac national park',
#   'north virginia',
#   'northumberland strait parlee beach shediac new brunswick signature natural attraction hopewell rocks half hour drive petitcodiac river valley confederation bridge prince edward island hour drive east moncton new brunswick several major attractions tidal bore phenomenon',
#   'extreme tides bay fundy',
#   'downstream flow petitcodiac river high tide causeway riverview',
#   'efforts',
#   'bridge order',
#   'river',
#   'property values',
#   'result'],
#  ['tun hussein onn national eye hospital thoneh'],
#  ['heterosexuals',
#   'moral environment',
#   'home american pro heterosexuality anti homosexuality organization',
#   'wayne lela based downers',
#   'illinois organization aim',
#   'bisexuals',
#   'homosexual activity organization',
#   'anti lgbtq',
#   'hate group southern poverty law center based propagation known falsehoods'],
#  ['prisurski nature reserve russian',
#   'strict ecological reserve northern volga uplands',
#   'east european plain protects study area forest steppe mixed forest sections',
#   'different parts',
#   'chuvashia largest sector alatyrski nature reserve located valley sura river mixed coniferous deciduous forests',
#   'two small steppe sections',
#   'southeast batyrevski jaltsjikski reserves',
#   'situated alatyr chuvash republic district chuvash republic',
#   'reserve',
#   'largest least disturbed area southern taiga lowland forest chuvashia',
#   'steppe habitat',
#   'habitat muskrat seasonal waterfowl reserve covers area',
#   'sq mi'],
#  ['information technology professional examination council itpec organization',
#   'information technology examinations',
#   'asian countries',
#   'information exchange',
#   'examination bodies',
#   'support international strategies',
#   'software development information technology human resources',
#   'november representatives countries',
#   'jitec ipa examination skill standards',
#   'common ip fe sw examinations examinations',
#   'loosely based japanese information technology',
#   'philippines thailand vietnam myanmar malaysia mongolia japan bangladesh countries',
#   'questions examination',
#   'member countries consistency',
#   'accurate measurement skills',
#   'region shares',
#   'one set skill standards'],
#  ['bath college domestic science small college bath',
#   'england',
#   'domestic subjects bath',
#   'green park',
#   'bath technical schools technical instruction act',
#   'local authorities power levy rate',
#   'education building instruction',
#   'subjects',
#   'carpentry joinery masonry',
#   'household high class cookery laundry work',
#   'stitchery ornamental needlework local newspaper',
#   'history college',
#   'college',
#   'existence decision',
#   'classes',
#   'cookery sewing small number ladies',
#   'classes',
#   'merely efficient supervision domestic staff',
#   'woman',
#   'another purpose mind',
#   'teacher domestic subjects',
#   'accidental way college',
#   'standards',
#   'cater people',
#   'teachers',
#   'first group students',
#   'another miss lawrie',
#   'commemorative brochure bath spa university april temporary homes',
#   'various technical schools',
#   'new north extension guildhall miss lawrie',
#   'headmistress miss heygate miss w king',
#   'moved numbers',
#   'bath end',
#   'world war forty resident students',
#   'early days',
#   'college students',
#   'bright red blouse black full length skirt white apron',
#   'scarlet runners',
#   'domestic science college',
#   'brougham hayes',
#   'somerset industrial school boys',
#   'emergency wartime building taken admiralty college',
#   'elms',
#   'german bombing',
#   'original premises',
#   'green park',
#   'large private house',
#   'st winifreds sion hill',
#   'future home hostel students',
#   'somerset place',
#   'first overseas student',
#   'years',
#   'many commonwealth countries',
#   'student body course institutional management',
#   'war student residences',
#   'claverton manor work',
#   'building american museum britain',
#   'new building sion hill',
#   'war new domestic science college built cost',
#   'use september',
#   'northern slopes bath st winifreds',
#   'designed councillor hugh roberts teaching staff',
#   'e',
#   'b nielsen',
#   'post',
#   'new premises',
#   'place march history',
#   'special supplement local newspaper mark renovation bath abbey chronicle feature notes stones',
#   'premises',
#   'st winifred',
#   'place',
#   'final principal independent college miss',
#   'eileen',
#   'validation courses',
#   'university bristol college',
#   'bath college higher education',
#   'later bath spa university college bath spa university bachelor degrees',
#   'home economics secondary teaching',
#   'university bath',
#   'council national academic awards food based courses',
#   'new premises newton park',
#   'sion hill building',
#   'courses bath school art design',
#   'bath corsham court degree course developments',
#   'bsc',
#   'courses',
#   'human ecology food management human nutrition food nutrition consumer protection university',
#   'authority award degrees'],
#  ['swedish hospital',
#   'formerly swedish covenant hospital bed',
#   'teaching hospital located north side chicago illinois hospital',
#   'medical specialties',
#   'neurosurgery spine brain integrative cancer care heart services',
#   'electrophysiology women health services',
#   'emergency services hospital physicians',
#   'employees hospital',
#   'american osteopathic association healthcare facilities accreditation program swedish hospital',
#   'historically affiliated evangelical covenant church',
#   'swedish covenant church members',
#   'century',
#   'part northshore university healthsystem'],
#  ['ministry agriculture forestry water economy republic serbia serbian',
#   'ministarstvo',
#   'poljoprivrede umarstva vodoprivrede ministry government serbia',
#   'agriculture forestry water economy current minister aleksandar martinovi office'],
#  ['southland conference tournament',
#   'roadrunner field campus university texas san antonio san antonio texas',
#   'heavy rainfall san antonio area',
#   'postponement tournament start tournament winner texas state bobcats',
#   'southland conference',
#   'automatic bid ncaa division softball tournament championship game',
#   'espn remainder tournament streaming slc championship game',
#   'lincoln'],
#  ['university michigan marsal family school education education school university',
#   'public research university',
#   'undergraduate master doctoral degrees'],
#  ['scott tournament',
#   'canadian women national curling championship',
#   'champion',
#   'team',
#   'canada colleen jones',
#   'club halifax nova scotia',
#   'second straight hearts'],
#  ['alan alda center',
#   'science cross disciplinary organization',
#   'stony brook university school communication journalism stony brook',
#   'new york current director laura lindenfeld goal',
#   'scientists',
#   'policymakers students',
#   'media',
#   'alan alda actor writer science advocate',
#   'whose honor',
#   'brookhaven national laboratory cold spring harbor laboratory'],
#  ['triumph',
#   'hong kong drama television series',
#   'tvb',
#   'francis',
#   'flora chan joe myolie wu drama',
#   'pilots',
#   'fictional solar airways',
#   'based hong kong cathay pacific',
#   'however delayed due negotiations airline',
#   'support',
#   'sequel development filming',
#   'early months',
#   'titled triumph skies ii',
#   'tvb jade july triumph skies',
#   'nbc series lax',
#   'interest aviation',
#   'hong kong viewers',
#   'small doll',
#   'triangel',
#   'early series location filming',
#   'parafield airport adelaide memorable depth depiction flight training'],
#  ['science environmental health network',
#   'non profit organization',
#   'principal aim',
#   'law best practices',
#   'cumulative impacts',
#   'especially matters',
#   'public health environment',
#   'also keen advocate precautionary principle releasing number guidelines',
#   'principle actioned governments organizations'],
#  ['doctor education edd',
#   'latin educationis doctor doctor educationis depending region university research professional doctoral degree',
#   'field education',
#   'holder academic research administrative clinical professional positions',
#   'civil private organizations',
#   'public institutions',
#   'considerable differences',
#   'structure content',
#   'regions'],
#  ['nature park free park saint',
#   'john new brunswick canada',
#   'uptown area environmental retreat',
#   'intention',
#   'environment',
#   'total hectares acres',
#   'jd irving',
#   'october motor vehicle traffic irving nature park',
#   'royal astronomical society'],
#  ['izumo science center izumo kagakukan science center located izumo shi shimane prefecture japan',
#   'school center public education pupils izumo shi third grade junior high school',
#   'lessons',
#   'events',
#   'science manufacturing general public people',
#   'izumo science center park town mae station kita matsue line',
#   'museum'],
#  ['united states elections',
#   'tuesday november year election seats election united states congress special elections',
#   'year',
#   'none congressional seats',
#   'party hands',
#   'several gubernatorial races state legislative elections',
#   'several major cities',
#   'several types',
#   'local offices'],
#  ['grand hotel wien five star luxury hotel vienna austria',
#   'ringstra e k rntner ring'],
#  ['tuart forest national park national park south west region western australia kilometres mi south perth',
#   'largest remaining section',
#   'pure tuart forest world',
#   'traditionally state forest associated stand trees known ludlow state forest',
#   'frederick ludlow narrow strip tuart trees',
#   'ludlow capel busselton trees species eucalyptus gomphocephala',
#   'coastal limestone',
#   'area park home tallest largest specimens trees',
#   'park ft tall ft girth tuart drive kilometres mi length part bussell highway opening ludlow diversion',
#   'national park addition pure tuart forest park',
#   'largest remaining wild population western ringtail possum western ringtail possums brushtail possums',
#   'possum spotlighting trail',
#   'park',
#   'night types',
#   'mi',
#   'carpark',
#   'layman road'],
#  ['jonesboro economical transit system better known jets public transportation system',
#   'jonesboro largest city northeastern arkansas',
#   'three scheduled bus routes',
#   'service',
#   'individuals',
#   'regular fixed route bus service jets member arkansas transit association'],
#  ['hotel edison west th street midtown manhattan new york city',
#   'part',
#   'triumph hotels',
#   'brand owned shimmie horn gerald barad thomas edison',
#   'lights',
#   'accommodated guests floors',
#   'three restaurants',
#   'attempted mimic telephone number pennsylvania hotel pennsylvania',
#   'telephone exchange name circle herbert j krapp architect milton j kramer original owner hotel ballroom',
#   'broadway theatres arena theatre edison theatre',
#   'ballroom early glorious gloria parker orchestra hosted evening broadcast wor hotel edison parker',
#   'show glass harp musical glasses',
#   'popular latin sound marimba orchestra henry jerome band leader hotel',
#   'bill randle trio',
#   'signing dorsey burnette johnny burnette paul burlison management contract jerome',
#   'johnny daytime job elevator operator hotel',
#   'gac general artists',
#   'walking scene',
#   'luca brasi murder film',
#   'godfather filmed hotel',
#   'woody allen film bullets',
#   'broadway neil simon',
#   'seconds',
#   'hotel cafe michael keaton',
#   'hotel bar rum house film birdman'],
#  ['ncaa basketball tournaments',
#   'th year national collegiate athletic association philippines basketball tournaments',
#   'san sebastian stags',
#   'elimination',
#   'outright champions seniors division san beda red cubs',
#   'juniors division jrc light bombers'],
#  ['vitas healthcare provider end life care united states',
#   'hospice programs',
#   'district columbia vitas',
#   'professionals',
#   'average daily census patients',
#   'company website vitas subsidiary',
#   'publicly traded chemed corporation',
#   'plumbing company roto rooter'],
#  ['diploma education',
#   'diped graddiped postgraduate qualification',
#   'many commonwealth countries',
#   'australia sri lanka new zealand united kingdom'],
#  ['people indian film production company',
#   'indian actor arya studio',
#   'production arya tamil language films',
#   'films',
#   'boss engira bhaskaran vasuvum saravananum onna padichavanga arya',
#   'producer distributor production studio august cinema',
#   'prithviraj shaji',
#   'nadesan santosh sivan',
#   'malayalam language films'],
#  ['recreation park name',
#   'two different former baseball grounds',
#   'columbus ohio recreation park',
#   'street east side parsons',
#   'ramps interstate highway recreation park ii',
#   'schumacher place neighborhood bound schiller east whittier street south third base jaeger street west sources',
#   'th',
#   'street one block farther west ebner street east first base east kossuth street north right field home field columbus solons american association bulk site',
#   'giant eagle',
#   'south grant avenue remaining parts original large block residences november ohio state university football team',
#   'first home game recreation park ii historical marker',
#   'former site field october commemorate first ohio state home game loss wooster'],
#  ['gulliver',
#   'american animated musical fantasy film',
#   'max fleischer',
#   'dave fleischer fleischer',
#   'studios',
#   'cinemas united states december paramount pictures story loose adaptation jonathan swift novel name',
#   'story lilliput blefuscu centers',
#   'explorer',
#   'small kingdom',
#   'war argument wedding song film fleischer studios',
#   'length animated film',
#   'well second animated feature film',
#   'american studio walt disney productions',
#   'seven dwarfs paramount commissioned feature response success film sequences film',
#   'seymour kneitel willard bowsky',
#   'tom palmer grim natwick william henning roland crandall thomas johnson robert leffingwell frank kelling winfield hoskins',
#   'calpini'],
#  ['tensas river national wildlife refuge protected wildlife area',
#   'northeastern louisiana usa'],
#  ['einaudi institute economics finance eief italian istituto einaudi',
#   'l economia e la finanza italian based institution',
#   'research economics',
#   'bank italy',
#   'two graduate programs',
#   'msc economics rome masters economics rome phd economics rome economics doctorate red',
#   'english official degree rome',
#   'luiss official degree red',
#   'luiss university rome tor vergata',
#   'jointly institute builds tradition predecessor ente luigi einaudi',
#   'economic research italy',
#   'fifty years',
#   'einaudi institute economics finance',
#   'italian politician economist',
#   'luigi einaudi',
#   'research emphasis policy',
#   'relevant topics',
#   'influence public thinking train',
#   'seminar series graduate level courses conferences'],
#  ['union german academies sciences',
#   'german union der deutschen akademien der',
#   'short akademienunion umbrella organization',
#   'eight german academies sciences humanities union',
#   'scientists',
#   'various disciplines',
#   'scientific exchange collaboration',
#   'member academies',
#   'large scale research projects',
#   'early career researchers'],
#  ['tianjin health industry park professional tennis tournament',
#   'outdoor hard courts',
#   'third edition tournament part',
#   'women circuit',
#   'total prize money',
#   'place'],
#  [],
#  ['wellington region local elections',
#   'wider new zealand local elections',
#   'elect members',
#   'national councils boards elections',
#   'one regional council',
#   'greater wellington regional council',
#   'three district health boards',
#   'various community boards licensing trusts'],
#  ['tristar airlines airline based mccarran international airport las vegas nevada',
#   'operations',
#   'july scheduled flights',
#   'los angeles san francisco',
#   'added destinations',
#   'later year tristar utilized british aerospace aircraft routes',
#   'late airline',
#   'financial difficulties',
#   'scheduled operations',
#   'charter industry',
#   'settled lessor dispute november tristar',
#   'flights'],
#  ['hamburg wadden sea national park german hamburgisches',
#   'three german wadden sea national parks',
#   'single ecological entity',
#   'wadden sea reaching den helder esbjerg exclave city state hamburg north germany',
#   'km cuxhaven estuary elbe north sea german bight',
#   'islands neuwerk',
#   'nigeh',
#   'plaaten dune islands national park',
#   'wadden sea world heritage site',
#   'intact intertidal ecosystem importance breeding area',
#   'many species birds',
#   'uniquely high biodiversity'],
#  ['article',
#   'summary results general elections canadian territory yukon unicameral legislative body yukon legislative assembly',
#   'territorial council number members yukon assembly',
#   'increased time six appointed members',
#   'late eight two elected yukon first election current nineteen elected legislative body yukon yukon territorial council body',
#   'primary government non partisan advisory body commissioner yukon',
#   'ability',
#   'appointed members mixture',
#   'elected members political parties',
#   'pre elections',
#   'fell use parties',
#   'yukon legislative assembly',
#   'yukon',
#   'multi member districts',
#   'early history',
#   'two members',
#   'time districts',
#   'single member districts',
#   'electoral district',
#   'one member',
#   'first past post yukon legislative assembly political parties',
#   'information',
#   'graphically recent elections',
#   'introduction political parties',
#   'yukon party',
#   'yukon progressive conservative party',
#   'political parties',
#   'six ten elections',
#   'three elections',
#   'liberal party',
#   'two elections'],
#  ['island hotel casino racetrack',
#   'downs greyhound racino',
#   'located wheeling island middle ohio river part city',
#   'west virginia',
#   'located wheeling island exit',
#   'two hours east columbus ohio casino',
#   'approximately one hour southwest pittsburgh pennsylvania',
#   'january',
#   'united states',
#   'mardi gras casino resort nitro west virginia owned delaware north'],
#  ['whirl sex politics',
#   'italian metalmeccanico',
#   'un turbine di sesso e politica',
#   'worker hairdresser italian comedy film',
#   'lina wertm ller'],
#  ['sec women basketball tournament',
#   'place',
#   'bridgestone arena',
#   'nashville tennessee march tennessee lady volunteers tournament',
#   'sec automatic bid ncaa women basketball tournament',
#   'lsu lady',
#   'championship game'],
#  ['men ice hockey tournament rd conference playoff league history',
#   'march march first round games',
#   'home team campus sites',
#   'four matches',
#   'civic center',
#   'st paul minnesota',
#   'winning tournament northern michigan',
#   'broadmoor trophy',
#   'automatic bid ncaa division men ice hockey tournament'],
#  ['economic forum annual international meeting economic political elites',
#   'first half september ski spa resort karpacz poland forum',
#   'warsaw',
#   'eastern davos according organisers mission economic forum',
#   'favorable climate development',
#   'political economic cooperation europe opinions forum speakers',
#   'international media',
#   'leading analysts forum',
#   'political business nonprofit leaders',
#   'th edition economic forum',
#   'visitors countries'],
#  ['world sports',
#   'airs monday thursday pm pm',
#   'sam mcclure running years highest rating sports radio show melbourne show',
#   'sportsday sports'],
#  ['techmania science center',
#   'one first science centers',
#   'czech republic institution informal education project',
#   'koda transportation joint stock company university west bohemia plze intention',
#   'modern interactive center',
#   'often known science center industrial estate koda company mission techmania',
#   'especially young people',
#   'another goal point',
#   'next generation young visitors science center',
#   'answers science center',
#   'gates',
#   'visitors',
#   'science engineering interactive environment',
#   'science center based explanations',
#   'particular physical mathematical principles',
#   'game',
#   'activities interactivity activities',
#   'visitors',
#   'exhibits',
#   'main exhibitions edutorium',
#   'physics based exhibits categories',
#   'optics mechanic electricity magnetism acoustics part techmania',
#   'physical phenomenon techmania visitors',
#   'high school groups',
#   'collection brain',
#   'scientific toys exhibition koda',
#   'story koda company',
#   'example world unique locomotives trolleybus steam engine year',
#   'steam power',
#   'september march controversial artwork entropa',
#   'techmania science center',
#   'september total renovation first planetarium czech republic',
#   'part',
#   'new techmania november main hall science center',
#   'march',
#   'new interactive exhibitions',
#   'example',
#   'renewable sources energy physics human body water world',
#   'example',
#   'many phenomena',
#   'special topics'],
#  ['wasgamuwa national park natural park sri lanka',
#   'matale polonnaruwa districts',
#   'protect',
#   'refuge',
#   'development project',
#   'one four national parks',
#   'project',
#   'originally designated nature reserve early area',
#   'strict nature reserve',
#   'one protected areas',
#   'sri lankan elephants',
#   'large herds',
#   'also one important bird areas sri lanka name',
#   'wasgamuwa',
#   'derived words',
#   'walas',
#   'wood park'],
#  ['university information science technology',
#   'st paul apostle macedonian',
#   'univerzitet',
#   'total students',
#   'university uist',
#   'parliament republic macedonia act establishment university information technology students uist',
#   'first supercomputer cluster computer republic north macedonia international outreach university results',
#   'multinational student population countries',
#   'undergraduate master programs',
#   'academic ranking world universities uist',
#   'top university north macedonia universities'],
#  ['political crisis',
#   'tunisia',
#   'assassination leftist leader mohamed brahmi',
#   'late july country',
#   'mainly secular opposition',
#   'several protests ruling troika alliance dominated rashid al ghannushi islamist ennahda movement events',
#   'abidine ben ali',
#   'general election',
#   'ennahda win plurality',
#   'moncef marzouki',
#   'congress republic cpr crisis',
#   'prime minister ali laarayedh',
#   'new constitution',
#   'many incidents',
#   'protests',
#   'assassination prominent secular leaders chokri',
#   'february mohamed brahmi july factors',
#   'government failure deal rise hardline salafist groups',
#   'ansar al sharia',
#   'assassinations',
#   'security personnel state institutions',
#   'government list group terrorist organization',
#   'growing pressure opposition groups protests',
#   'october thousands demonstrators',
#   'streets',
#   'government step hours talks ruling islamist coalition opposition leaders',
#   'ennahda promising resign',
#   'three weeks ending months old political deadlock exchange ennahda resignation opposition',
#   'pass constitution freedom worship guaranteed time',
#   'greater role religion public life'],
#  ['forbidden education',
#   'la educaci',
#   'n prohibida independent documentary',
#   'film documents',
#   'diverse alternative education practices',
#   'unconventional schools latin america spain',
#   'educational approaches popular education montessori progressive education waldorf homeschooling',
#   'first released movie spanish funded crowdfunding methodology',
#   'distributed screening proposal',
#   'release cities countries',
#   'one week release movie',
#   'almost million times film',
#   'creative commons attribution',
#   'noncommercial sharealike license'],
#  ['market cross scots mercat cross structure',
#   'mark market square market towns',
#   'regular market',
#   'fair granted monarch bishop baron'],
#  ['three hotels',
#   'malaysia hotels',
#   'london vista hotel limited part malayan united industries brand name',
#   'regal hotel group order',
#   'regal hotels'],
#  ['ministry education science technology albanian ministria e arsimit shkenc teknologjis dhe inovacionit department government kosovo responsible policy education science technology kosovo'],
#  ['american athletic conference women basketball tournament tournament',
#   'march mohegan sun arena uncasville connecticut connecticut third straight american athletic conference title',
#   'south florida',
#   'automatic trip ncaa women basketball tournament'],
#  ['traveller debut studio album american singer songwriter chris stapleton album',
#   'stapleton',
#   'music publications old school country southern rock record traveller',
#   'critical acclaim',
#   'several awards',
#   'album year country music association awards',
#   'th grammy awards album year',
#   'also best country',
#   'solo performance academy country music awards album year song',
#   'nobody',
#   'year billboard music award',
#   'number one us billboard chart country music association awards stapleton justin timberlake',
#   'quadruple platinum recording industry association america riaa',
#   'million copies',
#   'united states november',
#   'country album',
#   'three singles traveller',
#   'nobody',
#   'parachute',
#   'nobody blame',
#   'top country airplay chart album track fire',
#   'accompanied music video',
#   'radio single album track tennessee whiskey',
#   'popularity',
#   'performance',
#   'aforementioned cma awards',
#   'number one billboard hot country songs',
#   'chart number'],
#  ['border security economic opportunity immigration modernization act bill proposed immigration reform bill',
#   'sen charles schumer ny united states senate bill co',
#   'eight bipartisan group u senators',
#   'negotiated bill introduced senate april th united states congress senate judiciary committee',
#   'hearings bill april bill voted committee',
#   'senate calendar june senate',
#   'bill margin bill',
#   'republican controlled united states house representatives',
#   'th congress',
#   'possible many illegal immigrants',
#   'legal status',
#   'eventually citizenship',
#   'border security',
#   'border patrol agents',
#   'new visas',
#   'visa entrepreneurs',
#   'lower skilled workers',
#   'additional visas',
#   'green cards',
#   'billion youth jobs program',
#   'diversity visa lottery favor',
#   'prospective legal immigrants',
#   'already united states non partisan congressional budget office estimated bill',
#   'fiscal deficit',
#   'us',
#   'billion years billion social security administration',
#   'billion revenue'],
#  ['foodroutes network frn headquartered arnot pennsylvania united states national non profit organization',
#   'support variety',
#   'localized groups',
#   'sustainable agriculture community based food systems goal introduce',
#   'americans',
#   'food seeds',
#   'farmers',
#   'routes',
#   'farm tables',
#   'national coordinator',
#   'fresh buy local chapter network',
#   'visible efforts series marketing campaigns',
#   'consumers',
#   'eating local food frn',
#   'website consumers',
#   'farms areas',
#   'direct public',
#   'restaurants',
#   'locally grown food'],
#  ['australian sports sedan championship cams',
#   'motor racing title sports sedans',
#   'th australian sports sedan championship tasmanian kerry',
#   'toyota celica supra'],
#  ['hell gate national park national park',
#   'lake naivasha kenya park',
#   'narrow break cliffs',
#   'tributary prehistoric lake',
#   'early humans',
#   'rift valley',
#   'park notable wide variety wildlife scenery',
#   'fischer tower central tower columns hell gate gorge national park',
#   'five geothermal power stations',
#   'olkaria park',
#   'three basic campsites',
#   'maasai cultural center',
#   'education maasai culture traditions'],
#  ['sickle cell disease scd',
#   'sickle cell group hemoglobin',
#   'related blood disorders',
#   'common type known sickle cell anemia sickle cell anemia',
#   'abnormality oxygen',
#   'protein haemoglobin',
#   'red blood cells',
#   'red blood cells',
#   'abnormal sickle',
#   'shape',
#   'certain circumstances',
#   'unable deform',
#   'capillaries',
#   'blockages problems',
#   'sickle cell disease',
#   'months',
#   'age number health problems',
#   'attacks',
#   'pain known sickle cell crisis joints anemia swelling hands',
#   'feet bacterial infections',
#   'stroke probability severe symptoms',
#   'age',
#   'treatment people',
#   'adulthood good healthcare median life expectancy years',
#   'major organs',
#   'sickle cell disease liver heart kidneys',
#   'joints',
#   'damage abnormal functions sickle cells',
#   'inability',
#   'small blood vessels',
#   'correctly sickle cell disease',
#   'person',
#   'two abnormal copies globin gene',
#   'haemoglobin',
#   'one parent several subtypes',
#   'exact mutation haemoglobin gene attack',
#   'temperature changes',
#   'dehydration high altitude person',
#   'single abnormal copy',
#   'usually symptoms',
#   'sickle cell trait people',
#   'carriers diagnosis blood test countries',
#   'babies birth disease diagnosis',
#   'also possible pregnancy care people',
#   'cell disease',
#   'infection prevention vaccination antibiotics high fluid intake folic acid supplementation pain medication measures',
#   'blood transfusion medication hydroxycarbamide hydroxyurea new gene therapies',
#   'genetic modification replacement blood forming stem cells bone marrow scd',
#   'million people',
#   'annual deaths contributory factor deaths',
#   'sub saharan africa',
#   'lesser degree parts india southern europe west asia north africa',
#   'people african origin sub saharan living parts world condition',
#   'medical literature american physician james b herrick genetic transmission',
#   'e',
#   'v neel established carriers abnormal gene degree',
#   'malaria'],
#  ['trans type cars', 'australia sports sedans'],
#  ['la rabida children',
#   'lifelong medical conditions',
#   'south side chicago lake michigan facility',
#   'la rabida',
#   'approximately children',
#   'primary specialty care address complex challenging medical conditions hospital',
#   'care patients',
#   'family ability',
#   'treatment chronic illnesses',
#   'asthma',
#   'sickle cell disease developmental disabilities addition',
#   'la rabida',
#   'treatment children',
#   'experienced trauma',
#   'la rabida',
#   'national committee quality assurance ncqa medical home programs hospital',
#   'joint commission gold seal approval'],
#  ['alberta',
#   'tournament hearts edition',
#   'alberta',
# ...
#   'plant animal',
#   'order',
#   'plant animal species',
#   'prehistoric habitations',
#   'societies',
#   'physical environment',
#   'present day important component analyses',
#   'study site formation processes field',
#   'particularly useful artifacts',
#   'excavated surveyed site cases earth movement erosion',
#   'artifacts archaeological features specialist sub fields example bioarchaeology geomorphology defined materials study term environmental used general template order',
#   'general field scientific inquiry',
#   'time periods',
#   'geographical regions',
#   'archaeology whole'],
#  ['tokyo friends movie movie japanese film',
#   'kozo nagayama film extension original drama series',
#   'tokyo friends',
#   'plot film',
#   'ai otsuka debut theatre'],
#  ['united states military darpa nasa',
#   'advancements engineering gas turbine engines',
#   'military aircraft',
#   'ihptet designated goals',
#   'three engine classes',
#   'turbofan turbojet turboprop turboshaft expendable engines turbofan class primary goal',
#   'double engine thrust weight ratio program',
#   'many significant developments employed aircraft f joint strike fighter',
#   'explicit goals',
#   'versatile affordable advanced turbine engines',
#   'program'],
#  ['multi party system',
#   'three dominant political parties',
#   'extreme difficulty',
#   'anybody',
#   'electoral success banner party',
#   'extent fault lines',
#   'politics',
#   'historically dominant colorado national parties',
#   'underwent',
#   'intermittent series',
#   'civil wars',
#   'party system',
#   'reflected regional loyalties',
#   'colorado party',
#   'colorado national parties presidential elections',
#   'traditional loyalties',
#   'independence parties',
#   'members',
#   'national parties',
#   'leading figures',
#   'colorado national parties civilian military administrations',
#   'role',
#   'long term traditional party loyalties',
#   'somewhat critics',
#   'two parties',
#   'extent',
#   'willingness',
#   'prominent members',
#   'civilian military administrations supporters',
#   'difficult circumstances years question participation',
#   'colorado national members civilian military administrations background political figures',
#   'part country affairs circumstances',
#   'ferreira aldunate seregni',
#   'first return democracy elections',
#   'julio mar sanguinetti',
#   'uruguayan electorate willingness',
#   'traditional parties',
#   'major parties',
#   'broad front fact coalition autonomous political parties',
#   'ideological outlook colorado national parties',
#   'divergent factions autonomous identities',
#   'parties'],
#  ['student teacher ratio student faculty ratio number students',
#   'school university',
#   'divided number teachers institution example student teacher ratio',
#   'students',
#   'every teacher term',
#   'create teacher student ratio related measure staff child ratio number children childcare staff member family childcare provider responsible supervising ratio',
#   'proxy class size',
#   'various factors',
#   'student teacher ratio',
#   'significantly lower average class size grade level varied student teacher ratio average ratio',
#   'four year old preschoolers',
#   'children',
#   'crucial developmental stage',
#   'fundamental skills',
#   'social interaction self regulation',
#   'basic academic concepts',
#   'supportive nurturing environment',
#   'strong foundation',
#   'future',
#   'teacher student ratio low age children',
#   'supervision help classroom time',
#   'hayenga children',
#   'difficult teachers',
#   'attention',
#   'one pupil classroom low student teacher ratio primary school ratio students teachers',
#   'grade age',
#   'hayenga average teacher student ratio public primary schools united states children',
#   'classes',
#   'different courses',
#   'middle school',
#   'average time subjects children',
#   'middle school',
#   'several class issues',
#   'teachers classes',
#   'declining children',
#   'many firsts',
#   'high school classes',
#   'stage children',
#   'adults',
#   'united states average teacher student ratio public schools less pupils class',
#   'research student teacher ratios',
#   'developed nations primary education organisation economic co operation development oecd member countries average student teacher ratio elementary school',
#   'brazil mexico hungary luxembourg'],
#  ['university',
#   'faculty political science montenegrin',
#   'kih nauka',
#   'one educational institutions university montenegro building',
#   'located podgorica shared university faculty law faculty',
#   'leading educational institution'],
#  ['australian market social research society',
#   'amsrs professional membership body',
#   'approximately market research professionals',
#   'standards awareness market social research australia',
#   'principal aims',
#   'professional standards ethics',
#   'social research assist members career development',
#   'amsrs representative body individual market social research professionals association market social research organisations',
#   'peak representative body market social research organisations',
#   'two peak societies',
#   'market',
#   'social research help',
#   'highest ethical technical standards',
#   'industry regulatory legislative interests',
#   'closely association market social research organisations'],
#  ['mater women children hospital hyde park townsville queensland',
#   'sisters mercy mater health services',
#   'north queensland',
#   'competing private obstetric hospital wesley park hospital'],
#  ['dr west medicine',
#   'american psychedelic rock band',
#   'chicago',
#   'billboard hot band members greenbaum vocals bonnie',
#   'zee',
#   'guitar vocals jack carrington guitar vocals percussion evan engber percussion'],
#  ['list events'],
#  ['ballarat wildlife park wildlife park ballarat victoria',
#   'privately owned founder greg parker wife julia leonard hectare park',
#   'animals',
#   'australian animals',
#   'kangaroos extensive collection reptiles',
#   'well known housing patrick common wombat oldest known marsupial captivity'],
#  ['yellow band disease',
#   'colonies',
#   'coral time coral',
#   'pollution overfishing climate change',
#   'large blotches',
#   'yellowed tissue caribbean scleractinian corals yellow band disease bacterial infection',
#   'coral',
#   'discolored bands',
#   'surface infected coral colony lesions locations bacteria',
#   'coral symbiotic photosynthetic algae',
#   'zooxanthellae major energy source coral cellular damage loss major energy source',
#   'coral',
#   'coral death evidence climate change',
#   'disease'],
#  ['horizon league men basketball tournament',
#   'march march joe louis arena detroit winner tournament',
#   'horizon league',
#   'automatic berth ncaa men basketball tournament',
#   'first horizon league tournament',
#   'since played predetermined neutral site'],
#  ['great river national wildlife refuge',
#   'km',
#   'miles km mississippi river',
#   'north st louis missouri three separate units',
#   'floodplain illinois missouri sides',
#   'great river refuge',
#   'globally important bird area',
#   'due value shorebirds',
#   'refuge proximity st louis',
#   'excellent educational opportunities',
#   'large population clarence cannon national wildlife refuge',
#   'also administration great river refuge great river refuge turn',
#   'national wildlife refuge complex',
#   'port louisa',
#   'two rivers',
#   'middle mississippi'],
#  ['food libel laws',
#   'food disparagement laws',
#   'libel laws laws',
#   'thirteen u states',
#   'easier food producers',
#   'critics',
#   'thirteen states',
#   'alabama arizona colorado florida georgia idaho louisiana mississippi north dakota ohio oklahoma south dakota texas many food disparagement laws',
#   'lower standard civil liability',
#   'punitive damages attorney fees plaintiffs',
#   'regardless case outcome laws',
#   'significantly state state food libel laws',
#   'food manufacturer processor sue person group',
#   'disparaging comments food products',
#   'different standards proof',
#   'traditional american libel lawsuits',
#   'practice placing burden proof party',
#   'reporting facts',
#   'amounts lead',
#   'counter calcium supplements'],
#  ['catoctin wildlife preserve acre ha zoo wildlife preserve acres',
#   'accessible public located maryland route thurmont maryland united states',
#   'features safari truck rides',
#   'visitors',
#   'large herbivores'],
#  ['environmental benefits',
#   'energy technologies',
#   'widely recognised contribution',
#   'energy security',
#   'energy security electricity generation heat supply transportation',
#   'renewable energy',
#   'global level',
#   'renewable energy technologies',
#   'self sufficient energy systems',
#   'energy dependencies',
#   'countries'],
#  ['monash children',
#   'hospital melbourne',
#   'victoria largest neonatal intensive care unit',
#   'full range specialist services',
#   'surgical care oncology rehabilitation services home victoria dedicated children',
#   'science state wide referral service thalassemia provider fetal surgery services partnership',
#   'royal women hospital mercy hospital women melbourne services',
#   'adult service',
#   'hospital',
#   'older move adult service'],
#  ['shannondale springs wildlife management area',
#   'charles town west virginia jefferson county shannondale springs',
#   'located acres',
#   'brushy areas',
#   'open fields',
#   'located miles km east charles town',
#   'shenandoah river access charles town',
#   'state route mission road south mission road'],
#  ['rac tourist trophy motor race sports cars',
#   'place',
#   'september roads',
#   'dundrod county antrim northern ireland st rac tourist trophy fifth race world sportscar championship tourist trophy',
#   'handicap winners',
#   'paul armagnac g rard laureau',
#   'hbr panhard',
#   'overall race win championship points',
#   'mike hawthorn maurice trintignant',
#   'ferrari monza',
#   'race ferrari leading world sportscar championship',
#   'lancia victory italian marque',
#   'title',
#   'second season'],
#  ['canadian wartime elections',
#   'french loi des lections',
#   'en temps de guerre bill',
#   'robert borden conscription crisis',
#   'conservatives',
#   'canadian unionist government bill explicit attempt',
#   'votes government',
#   'women',
#   'federal elections act',
#   'vote wives widows mothers',
#   'sisters soldiers',
#   'overseas first women',
#   'ever able vote',
#   'canadian federal elections',
#   'strongly favour conscription act',
#   'enemy alien citizens',
#   'relatives',
#   'armed forces',
#   'primarily german ukrainian polish canadians',
#   'german austro hungarian empires',
#   'partially disenfranchised years first provincial federal elections municipal school board elections',
#   'politicians',
#   'leader',
#   'vote',
#   'bloc influence election time act',
#   'justified patriotic fever',
#   'world war',
#   'disenfranchised opponents government widely supported majority canadians',
#   'coupled military voters',
#   'skewed vote favour',
#   'two laws',
#   'government',
#   'large enough margin',
#   'laws',
#   'french canadians',
#   'recent immigrants',
#   'liberal decades',
#   'conservative party war act',
#   'dominion elections act',
#   'assented july women',
#   'notably aboriginal women',
#   'property'],
#  ['environmental registry registry online database ontario government ministries',
#   'environmentally significant proposals decisions',
#   'public submit comments ministries',
#   'environmental bill rights',
#   'comments',
#   'final decisions',
#   'environmental commissioner ontario',
#   'various ministries',
#   'registry',
#   'well considered comments',
#   'operated ministry environment',
#   'www ebr gov',
#   'wayback machine'],
#  ['canadian historians',
#   'focus history canada economy',
#   'far fewer political economic religious military conflicts',
#   'canadian history societies',
#   'many prominent english canadian historians',
#   'economic historians',
#   'europe united states frameworks study',
#   'canada',
#   'heavily marxist influenced economic history',
#   'europe little relevance canadian history focus class urban areas',
#   'industry',
#   'address',
#   'canada rural resource based economy',
#   'similarly monetarist school',
#   'powerful',
#   'united states',
#   'economic history',
#   'canada',
#   'many years dominant school thought',
#   'thesis school',
#   'canadian economy study natural resources approach used study',
#   'early european history canadian economy',
#   'canadian economy time developed exploitation series staples',
#   'europe',
#   'thesis',
#   'canada australia',
#   'many developing nations arrival europeans',
#   'first nations',
#   'canada large vibrant trade network furs',
#   'decorative items goods',
#   'thousands kilometres',
#   'many rivers',
#   'region'],
#  ['kosher foods foods',
#   'jewish dietary regulations',
#   'kashrut dietary law laws kashrut',
#   'food',
#   'living creatures',
#   'kosher foods',
#   'certain types',
#   'mammals birds',
#   'specific criteria flesh animals',
#   'criteria forbidden dietary laws',
#   'kosher mammals birds',
#   'process known shechita blood',
#   'meat process',
#   'soaking water meat permissible use plant based products',
#   'fruits vegetables grains',
#   'spices',
#   'certain produce grown land',
#   'israel',
#   'requirements',
#   'kosher food',
#   'meat dairy products meat products',
#   'kosher meat beef lamb venison kosher poultry chicken goose duck turkey derivatives',
#   'meat animal gelatin non animal products processed equipment',
#   'meat meat',
#   'derived products',
#   'belong category dairy products',
#   'milk derivatives butter cheese non dairy products processed equipment',
#   'milk milk derived products',
#   'category categorization meat milk respective derivatives',
#   'kosher foods separate equipment storage preparation meat based dairy based foods',
#   'order food',
#   'kosher another category kosher food',
#   'neither meat milk derivatives',
#   'foods fish eggs',
#   'birds',
#   'grains',
#   'equipment',
#   'meat dairy products',
#   'complexities',
#   'modern food manufacturing kashrut agencies',
#   'production',
#   'kosher foods',
#   'certification',
#   'kosher food consumers',
#   'accordance jewish law jewish dietary law',
#   'primarily derived leviticus deuteronomy foods',
#   'jewish religious law',
#   'kosher english',
#   'pronunciation',
#   'fit context fit consumption foods accordance jewish law',
#   'hebrew r f'],
#  ['national film award best educational motivational instructional film one national film awards',
#   'annually directorate film festivals organisation',
#   'ministry information',
#   'india',
#   'one several awards',
#   'non feature films',
#   'rajat kamal silver lotus award',
#   'national film awards',
#   'short films',
#   'country indian languages',
#   'th national film awards award',
#   'national film award best promotional film national film award best scientific film national film award best investigative film national film award best exploration adventure film national film award best anthropological ethnographic film national film award best agriculture film national film award best film social issues',
#   'two new categories',
#   'best documentary best non feature film',
#   'social environmental values'],
#  ['eglinton tournament reenactment medieval joust revel',
#   'organized archibald earl eglinton',
#   'place',
#   'eglinton castle ayrshire queen beauty georgiana duchess',
#   'many distinguished visitors',
#   'part',
#   'prince louis napoleon future emperor french tournament deliberate act romanticism',
#   'spectators',
#   'primarily known ridicule',
#   'whigs',
#   'problems',
#   'rainstorms',
#   'whatever opinion',
#   'success tournament imitation',
#   'ancient manners customs',
#   'one feeling admiration',
#   'gorgeousness whole scene',
#   'pageant',
#   'even wednesday procession',
#   'greatest possible disadvantage dullest eye glistened delight lengthy stately train swept marshalled lists participants',
#   'regular training preparations',
#   'many works art',
#   'century',
#   'events',
#   'lavish tournament brussels',
#   'historical reenactments',
#   'present features tournament',
#   'walter scott novel ivanhoe',
#   'living enactment literary romances',
#   'aware manifold deficiencies exhibition',
#   'imagination',
#   'something',
#   'revival chivalry others',
#   'profit lord eglinton',
#   'losses',
#   'earl granddaughter viva montgomerie recalled memoirs',
#   'wealth estate'],
#  ...]
